# %%
import pandas as pd
import os 
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules 
#from mlxtend.preprocessing import OnehotTransactions

# %%
#importing modules
import os 
print('importing "os" operating system')
from io import BytesIO
#from urllib.request import urlopen
from zipfile import ZipFile
import pandas as pd
print('pandas')
import numpy as np
import geopandas as gpd
print('geopandas')
from shapely.geometry import Point
print('shapely')
import numpy as np
print('numpy')
from statsmodels.tsa.stattools import grangercausalitytests
print('statsmodels')
import pysal as ps
#print('pysal')
import seaborn as sns
print('seaborn')
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
print('matplotlib')


# %matplotlib inline
# Out:
# importing "os" operating system
# pandas
# geopandas
# shapely
# numpy
# statsmodels
# C:\Users\Ahmed.Askar\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql
# seaborn
# matplotlib

# %%
from scipy.spatial.distance import squareform
from scipy.spatial.distance import pdist, jaccard
#from sklearn.metrics import jaccard_similarity_score

#from sklearn.metrics import jaccard_similarity_score
from difflib import SequenceMatcher
import difflib as dfl

# %% [markdown]
# ## Approri part 2 and spatial auto

# %%
#drugname = 'tysabri' #, , , , 
#drugnamepath = drugname[:6]
#temporal = 'year'
#drugnamepath
#topk = 2

drugname = 'xarelto'#eliquis, xarelto, pradaxa
print('drugname: ', drugname)

drugnamepath = drugname[:6]
temporal = str('year')
drugnamepath
k=5
topk = 'top'+str(k)
        
#topk = 'tp'+str(k)
print('top k', k)
        #topk = 'tp10'
        #tpk
kk=k
# Out:
# drugname:  xarelto
# top k 5

# %%
#data_dirpath1 = r"D:\Research\FAERS_Public\Data\Analysis_Ready_data"+str('\\')+str(topk)+str('\\')+str(drugnamepath)+"_itemset_joinedPT\\"+str(temporal)+"_nai"
data_dirpath1 = r"D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai"
#data_dirpath1 = r"D:\Research\FAERS_Public\Data\Analysis_Ready_data"+str('\\')+str(drugnamepath)+"_itemset_joinedPT\\"+str(temporal)
os.chdir(data_dirpath1)
data_dirpath1
print(os.getcwd())
# Out:
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai

# %%
for filepath in os.listdir(data_dirpath1):
    itemset_filename = os.path.join(data_dirpath1, filepath)
    print(itemset_filename)
    itemset_filename= itemset_filename[62:-4]
    #print(filepath)
    print(itemset_filename)
# Out:
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\am_nai.csv
# am_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\at_nai.csv
# at_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ba_nai.csv
# ba_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\be_nai.csv
# be_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\bg_nai.csv
# bg_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\by_nai.csv
# by_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ch_nai.csv
# ch_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\cz_nai.csv
# cz_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\de_nai.csv
# de_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\dk_nai.csv
# dk_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ee_nai.csv
# ee_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\es_nai.csv
# es_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\fi_nai.csv
# fi_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\fr_nai.csv
# fr_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\gb_nai.csv
# gb_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ge_nai.csv
# ge_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\gr_nai.csv
# gr_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\hr_nai.csv
# hr_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\hu_nai.csv
# hu_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ie_nai.csv
# ie_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\is_nai.csv
# is_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\it_nai.csv
# it_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\lt_nai.csv
# lt_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\lu_nai.csv
# lu_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\lv_nai.csv
# lv_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\nl_nai.csv
# nl_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\no_nai.csv
# no_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\pl_nai.csv
# pl_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\pt_nai.csv
# pt_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ro_nai.csv
# ro_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\se_nai.csv
# se_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\si_nai.csv
# si_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\sk_nai.csv
# sk_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\tr_nai.csv
# tr_nai
# D:\Research\FAERS_Public_Similarity\Data\itemset_joinedPT\nai\ua_nai.csv
# ua_nai

# %%
import glob
import os
import pandas as pd
#count use top ten
#path = os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\new_temp")
#allFiles = glob.glob(path + "/*.csv")
rowcount_itemset = []
row_count_itemset_dict = {}
itemset_filenames = []

for filepath in os.listdir(data_dirpath1):
    itemset_filename = os.path.join(data_dirpath1, filepath)
    #if temporal == 'quarter':
    df_itemset = pd.read_csv(itemset_filename)
   # display(df_itemset)
    rowcount_itemset.append(len(df_itemset.index))
    itemset_filename= itemset_filename[62:-4]
    #print(rowcount_itemset)
    itemset_filenames.append(itemset_filename)

    #itemset_filename= itemset_filename[62:-4]
    row_count_itemset_dict = dict(zip(itemset_filenames, rowcount_itemset))
    
    y = row_count_itemset_dict.values()
print((y))

print(itemset_filename)
    #ymin = (min(y))
   # ymax = (max(y))
   # print(min(y))
   # print(max(y))

#print(min(y))

#print(itemset_filename)
#itemset_filename
# Out:
# dict_values([127, 1, 7, 2, 2, 1, 2, 1, 1, 4457, 1, 1, 1, 1, 1, 4, 5, 2, 1, 1, 8, 1, 42, 3, 1, 257, 3, 3, 1, 25, 1, 3, 1, 5, 1])
# ua_nai

# %%
from collections import OrderedDict
sorted_row_count_itemset_dict = OrderedDict(sorted(row_count_itemset_dict.items(), key=lambda x: x[0]))
for x,y in zip(sorted_row_count_itemset_dict.keys(),sorted_row_count_itemset_dict.values()):
    #print(y)
    #if y < 4:
    if y >=1:
        print(y,x)
        pass
# Out:
# 127 am_nai
# 1 at_nai
# 7 ba_nai
# 2 be_nai
# 2 bg_nai
# 1 by_nai
# 2 ch_nai
# 1 cz_nai
# 1 de_nai
# 4457 dk_nai
# 1 ee_nai
# 1 es_nai
# 1 fi_nai
# 1 fr_nai
# 1 gb_nai
# 4 ge_nai
# 5 gr_nai
# 2 hr_nai
# 1 hu_nai
# 1 ie_nai
# 8 is_nai
# 1 it_nai
# 42 lt_nai
# 3 lu_nai
# 1 lv_nai
# 257 nl_nai
# 3 no_nai
# 3 pl_nai
# 1 pt_nai
# 25 ro_nai
# 1 se_nai
# 3 si_nai
# 1 sk_nai
# 5 tr_nai
# 1 ua_nai

# %%
from collections import OrderedDict
sorted_row_count_itemset_dict = OrderedDict(sorted(row_count_itemset_dict.items(), key=lambda x: x[0]))

# %%
df_itemset = pd.DataFrame()
df_itemset['Drug-OccuredCountry'] = sorted_row_count_itemset_dict.keys()
df_itemset['itemset-count'] = sorted_row_count_itemset_dict.values()
df_itemset= df_itemset.sort_values(by=['Drug-OccuredCountry'])
#saved_summary_ITTP = r"G:\Research\FAERS\Drug_Spatial\I_T_T_P\Data\Analysis_Ready_data\Approri\summary_of_approri_dataset"
#saved_summery_LBNE = r"G:\Research\FAERS\Drug_Spatial\L_B_N_E\Data\Analysis_ready_data\Approri\summary_of_approri_dataset"
#df_itemset.to_csv('df0dot2_lbne.csv')
df_itemset

df_itemset['occuredCountry'], df_itemset['temporal'] = df_itemset['Drug-OccuredCountry'].str.split('_', 1).str
#df_itemset.to_csv('df0dot2_lbne.csv')
df_itemset = df_itemset[df_itemset['occuredCountry']!=str('1delete')]
df_itemset
# Out:
# <ipython-input-60-14a4395099d0>:10: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df_itemset['occuredCountry'], df_itemset['temporal'] = df_itemset['Drug-OccuredCountry'].str.split('_', 1).str
#    Drug-OccuredCountry  itemset-count occuredCountry temporal
# 0               am_nai            127             am      nai
# 1               at_nai              1             at      nai
# 2               ba_nai              7             ba      nai
# 3               be_nai              2             be      nai
# 4               bg_nai              2             bg      nai
# 5               by_nai              1             by      nai
# 6               ch_nai              2             ch      nai
# 7               cz_nai              1             cz      nai
# 8               de_nai              1             de      nai
# 9               dk_nai           4457             dk      nai
# 10              ee_nai              1             ee      nai
# 11              es_nai              1             es      nai
# 12              fi_nai              1             fi      nai
# 13              fr_nai              1             fr      nai
# 14              gb_nai              1             gb      nai
# 15              ge_nai              4             ge      nai
# 16              gr_nai              5             gr      nai
# 17              hr_nai              2             hr      nai
# 18              hu_nai              1             hu      nai
# 19              ie_nai              1             ie      nai
# 20              is_nai              8             is      nai
# 21              it_nai              1             it      nai
# 22              lt_nai             42             lt      nai
# 23              lu_nai              3             lu      nai
# 24              lv_nai              1             lv      nai
# 25              nl_nai            257             nl      nai
# 26              no_nai              3             no      nai
# 27              pl_nai              3             pl      nai
# 28              pt_nai              1             pt      nai
# 29              ro_nai             25             ro      nai
# 30              se_nai              1             se      nai
# 31              si_nai              3             si      nai
# 32              sk_nai              1             sk      nai
# 33              tr_nai              5             tr      nai
# 34              ua_nai              1             ua      nai

# %%
#df_itemset.temporal.str[8:10]

# %%
#df_itemset.plot(x='occuredCountry', y='itemset-count')

idx=df_itemset.index.tolist()
x = range(len(idx))

plt.bar(x, df_itemset["itemset-count"].values)
plt.xticks(x, df_itemset["occuredCountry"]+df_itemset["temporal"].str[8:10].values, rotation=90)

sns.set(font_scale=3, rc={'figure.figsize':(50,50)})
plt.xticks(fontsize=30, rotation=90) #font size for x ticks, #rotation=90 rotate labels 90 degrees
plt.yticks(fontsize=30, rotation=90) #font size for x ticks, #rotation=90 rotate labels 90 degrees

#threshold = 10
#plt.axhline(color='k', linestyle=':', linewidth=15) #line across y=5


#plt.axhline(y=threshold, color='k', linestyle=':', linewidth=15) #line across y=5
#plt.axhline(y=threshold10, color='r', linestyle=':', linewidth=10)# line across y=10
plt.ylim((0,50))
#plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
#plt.box('off')
plt.title("Histogram of frequent itemsets -- max itemsets value=" + str(ymax) +", min itemsets value=" + str(ymin)+"temporal"+str(temporal)+"_drug_"+str(drugname))

figurepath = r"C:\Users\Ahmed.Askar\Desktop"
os.chdir(figurepath)

#plt.savefig("histogram_of_frequent_itemset__by_year"+str(temporal)+"_drug_"+str(drugname)+".png")
#plt.savefig("histogram_of_frequent_itemset_humira_by_year_min_sup_"+str(minsup)+"_drug_"+str(drug)+".svg")

#plt.show()

# %% [markdown]
# ### Frequency Itemset Mining

# %%
try:
    filename = []
    filename_itemsets_list = []
    for filepath in os.listdir(data_dirpath1):
        x = os.path.join(data_dirpath1, filepath)
        #print(data_dirpath1)

        #print(x)
        #if temporal == 'nai':
        u= x[62:-4]
        if u!=str('1delete_list'):
            print(u)     

            filename1 =u

            filename.append(filename1)
            filename1 = pd.read_csv(x)#, encoding='cp1252')#, sep='\[\'|\'\"\]|[ \'\"]*', header=None)
            #filename1 = filename1.nlargest(10,'support')# Need this for Frqunecy item the second way

            #filename1['itemsets'] = filename1.itemsets.str.strip(']') # Need this for Frqunecy item the second way
            #filename1['itemsets'] = filename1.itemsets.str.strip('[') # Need this for Frqunecy item the second way
            #filename1['itemsets'] = filename1.itemsets.str.strip('"') # Need this for Frqunecy item the second way
            #filename1['itemsets'] = filename1.itemsets.str.strip('"') # Need this for Frqunecy item the second way


            filename_itemsets = filename1['itemsets']

            filename_itemsets_list1 = []
            for x in filename_itemsets:
                x =str(x)
                x.split(',')
                filename_itemsets_list1.append(x)
            filename_itemsets_list1= set(filename_itemsets_list1)
            filename_itemsets_list.append(filename_itemsets_list1)

        dicts = {}

        dicts =dict(zip(filename, filename_itemsets_list))

except (KeyError, UnicodeDecodeError) as err: #AttributeError

    pass#print('error')
# Out:
# am_nai
# at_nai
# ba_nai
# be_nai
# bg_nai
# by_nai
# ch_nai
# cz_nai
# de_nai
# dk_nai
# ee_nai
# es_nai
# fi_nai
# fr_nai
# gb_nai
# ge_nai
# gr_nai
# hr_nai
# hu_nai
# ie_nai
# is_nai
# it_nai
# lt_nai
# lu_nai
# lv_nai
# nl_nai
# no_nai
# pl_nai
# pt_nai
# ro_nai
# se_nai
# si_nai
# sk_nai
# tr_nai
# ua_nai

# %%
#dictss =list(dicts.values())
#dictss
import pandas as pd
from itertools import chain, repeat

chainer = chain.from_iterable



Faers_comparision = pd.DataFrame({'spatiotemporal': list(chainer(repeat(k, len(v)) for k, v in dicts.items())),
                   'FaersValue': list(chainer(dicts.values()))})


spa= list(dicts.keys())
Faers_comparision['spatiotemporal']  = pd.DataFrame(spa, columns=['spatiotemporal'])
Faers_comparision.head()
# Out:
#   spatiotemporal                                         FaersValue
# 0         am_nai  {'   n renal vein thrombosis', 'ulmonary embol...
# 1         at_nai  {'   n pre-existing condition improved', '   d...
# 2         ba_nai                     {'   n renal vein thrombosis'}
# 3         be_nai  {'   drug ineffective', '   n pre-existing con...
# 4         bg_nai  {'   n pre-existing condition improved', '   n...

# %% [markdown]
# Faers_comparision = pd.DataFrame()
#
# Faers_comparision['spatiotemporal'] = dicts.keys()
#
# Faers_comparision['FaersValue'] = dictss#dicts.values()
#
# Faers_comparision.sort_values("spatiotemporal", inplace=True)
# Faers_comparision = Faers_comparision.reset_index(drop=True)
# Faers_comparision.head()

# %%
#Faers_comparision['spatial'], Faers_comparision['temporal'] = Faers_comparision['spatiotemporal'].str.split('_', 1).str
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].astype(str)

Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[2:]
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[:-2]
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].astype(str)
Faers_comparision['FaersValue']=Faers_comparision.FaersValue.str.split(',')

Faers_comparision.FaersValue = Faers_comparision.FaersValue.apply(str)
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[2:]
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[:-2]
Faers_comparision.head()
# Out:
#   spatiotemporal                                         FaersValue
# 0         am_nai     n renal vein thrombosis'", " 'ulmonary embo...
# 1         at_nai     n pre-existing condition improved'", " '   ...
# 2         ba_nai                            n renal vein thrombosis
# 3         be_nai     drug ineffective'", " '   n pre-existing co...
# 4         bg_nai     n pre-existing condition improved'", " '   ...

# %%
#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.strip()
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.lower()
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(u"/",", ")
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(u"\\\\", ", ")

#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(u"' ","'")

#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace('\n',"")
#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(' \n',"")
#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace('\n ',"")

#Faers_comparision['FaersValue'] = [''.join(c.split()) for c in Faers_comparision['FaersValue'].astype(str)]

Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r"\n",  ' ', regex=True)
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(r"[\"\']", '')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(',,,',',')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(',,',',')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[1:]
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str[:-1]
Faers_comparision.head()
# Out:
#   spatiotemporal                                         FaersValue
# 0         am_nai   renal vein thrombosis,  ulmonary embolism,   ...
# 1         at_nai   pre-existing condition improved,     drug ine...
# 2         ba_nai                               renal vein thrombosi
# 3         be_nai  rug ineffective,     n pre-existing condition ...
# 4         bg_nai   pre-existing condition improved,     n renal ...

# %%
#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.replace(r"[\"\']", '')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.lstrip(',')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.lstrip(', ')

Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.rstrip(',')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.rstrip(', ')
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.rstrip(' ,')


Faers_comparision.head()
# Out:
#   spatiotemporal                                         FaersValue
# 0         am_nai  renal vein thrombosis,  ulmonary embolism,    ...
# 1         at_nai  pre-existing condition improved,     drug inef...
# 2         ba_nai                               renal vein thrombosi
# 3         be_nai  rug ineffective,     n pre-existing condition ...
# 4         bg_nai  pre-existing condition improved,     n renal v...

# %%
Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].apply(lambda x: ', '.join(sorted(x.split(','))))
Faers_comparision.head()
# Out:
#   spatiotemporal                                         FaersValue
# 0         am_nai     n renal vein thrombosis'",  " '    spinal p...
# 1         at_nai     n pre-existing condition improved'",  " '  ...
# 2         ba_nai                            n renal vein thrombosis
# 3         be_nai     drug ineffective'",  " '   n pre-existing c...
# 4         bg_nai     n pre-existing condition improved'",  " '  ...

# %% [markdown]
# itemset_path = r"G:\Research\FAERS_Public\Data\Analysis_Ready_data\combined_Itemset\tp10"
# os.chdir(itemset_path)
# Faers_comparision.to_csv("itemset_FAERS_temporal_"+str(temporal)+"_drug_"+str(drugname)+"_top10_version_naive.csv")
# Faers_comparision[Faers_comparision['spatial']=='dk']

# %%
for filepath in os.listdir(data_dirpath1):
    x = os.path.join(data_dirpath1, filepath)
x[65:-4]
# Out:
# 'nai'

# %%
drugname 
drugnamepath = drugname[:6]
temporal_1
var = []
spatial_list = []
for filepath in os.listdir(data_dirpath1):
    x = os.path.join(data_dirpath1, filepath)
    #print(x[65:-4])
    #x= x[82:-4]
    #x= x[0:-2]
    if x[65:-4] == 'nai':
        var.append(x[62:-4])
        spatial_list.append(x[62:-8])
        
        temporal_nai = Faers_comparision.query("spatiotemporal == @var")
temporal_nai



countofcountries = int(len(temporal_nai.index))
countofcountries
# Out:
# 35

# %%
temporal_nai.FaersValue.loc[0]
#temporal_nai.FaersValue.loc[3]
# Out:
# "{'   n renal vein thrombosis', 'ulmonary embolism', '   drug ineffective', '  [deep vein thrombosis', '    spinal pain]'}"

# %%
temporal_nai.FaersValue.loc[3]
# Out:
# "{'   drug ineffective', '   n pre-existing condition improved'}"

# %%
def gestalt(a, b):
    
    return SequenceMatcher(None, a, b).ratio()
    #return SequenceMatcher(None, a, b).quick_ratio()
    #return SequenceMatcher(None, a, b).real_quick_ratio()

def jaccard_similarity(list1, list2):
    s1 = set(list1)
    s2 = set(list2)
    return float(len(s1.intersection(s2)) / len(s1.union(s2)))

# %% [markdown]
# ## Gestalt Pattern Matching

# %%
Gestalt = gestalt('cerebral  haemorrhage', 'cerebral  ischaemia')
print('Gestalt=', Gestalt )
# Out:
# Gestalt= 0.75

# %%
#Gestalt = gestalt(temporal_nai.FaersValue.loc[0], temporal_nai.FaersValue.loc[3])
#print('Gestalt=', Gestalt )

# %%
#Jaccard = scipy.spatial.distance.jaccard([temporal_nai.FaersValue.loc[0]], [temporal_nai.FaersValue.loc[3]])

#Jaccard = jaccard_similarity(list(temporal_nai.FaersValue.loc[0]), list(temporal_nai.FaersValue.loc[3]))

#print('Jaccard=', Jaccard )

# %% [markdown]
# ## jaccard_similarity

# %%
jaccard_similarity(list('cerebral  haemorrhage'), list('cerebral  ischaemia'))
# Out:
# 0.6923076923076923

# %% [markdown]
# ## cosine_similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
#corpus =temporal_nai.FaersValue.loc[0],temporal_nai.FaersValue.loc[3]
corpus = 'cerebral  haemorrhage', 'cerebral  ischaemia'

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(corpus)
words = vectorizer.get_feature_names()
cosine_similarity_matrix = cosine_similarity(tfidf)
cosine=list(cosine_similarity_matrix)
print('cosine=', cosine[1][0])
# Out:
# cosine= 0.33609692727625756

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-477-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
temporal_1fears = []
temporal_2fears = []
temporal_3fears = []
temporal_4fears = []

for row in temporal_1_.itertuples(index=True, name='Pandas'):
    temporal_1fears.append((getattr(row, "FaersValue")))
for row in temporal_2_.itertuples(index=True, name='Pandas'):
    temporal_2fears.append((getattr(row, "FaersValue")))
for row in temporal_3_.itertuples(index=True, name='Pandas'):
    temporal_3fears.append((getattr(row, "FaersValue")))
for row in temporal_4_.itertuples(index=True, name='Pandas'):
    temporal_4fears.append((getattr(row, "FaersValue")))

# %%
temporal_1_similiarity = []
temporal_2_similiarity = []
temporal_3_similiarity = []
temporal_4_similiarity = []
for i in range(0,countofcountries):#18
    for j in range(0,countofcountries):

    #print('row=',x)#
        #jaccard_distance(ifears[i],ifears[j])
        temporal_1_s = (similar(temporal_1fears[i],temporal_1fears[j]))
        #temporal_1_s = (temporal_1fears[i].corr(temporal_1fears[j], method='kendall'))

        temporal_2_s = (similar(temporal_2fears[i],temporal_2fears[j]))
        #temporal_2_s = (temporal_2fears[i].corr(temporal_2fears[j],method='kendall' ))

        temporal_3_s = (similar(temporal_3fears[i],temporal_3fears[j]))
       # temporal_3_s = (temporal_3fears[i].corr(temporal_3fears[j],method='kendall' ))

        temporal_4_s = (similar(temporal_4fears[i],temporal_4fears[j]))
        #temporal_4_s = (temporal_4fears[i].corr(temporal_4fears[j],method='kendall' ))

        
        temporal_1_similiarity.append(temporal_1_s)
        temporal_2_similiarity.append(temporal_2_s)
        temporal_3_similiarity.append(temporal_3_s)
        temporal_4_similiarity.append(temporal_4_s)

# %% [markdown]
# After Kendall Tau analysis or Frequent Itemset Mining

# %%
#matx = np.reshape(jaccard2, (38, 38))

temporal_1_matx = np.reshape(temporal_1_similiarity, (countofcountries, countofcountries))
temporal_2_matx = np.reshape(temporal_2_similiarity, (countofcountries, countofcountries))
temporal_3_matx = np.reshape(temporal_3_similiarity, (countofcountries, countofcountries))
temporal_4_matx = np.reshape(temporal_4_similiarity, (countofcountries, countofcountries))

# %%
temporal_1_df = pd.DataFrame(temporal_1_matx, index=spatial_list, columns=spatial_list)
temporal_2_df = pd.DataFrame(temporal_2_matx, index=spatial_list, columns=spatial_list)
temporal_3_df = pd.DataFrame(temporal_3_matx, index=spatial_list, columns=spatial_list)
temporal_4_df = pd.DataFrame(temporal_4_matx, index=spatial_list, columns=spatial_list)

temporal_1_comparison = 1-temporal_1_df
temporal_2_comparison = 1-temporal_2_df
temporal_3_comparison = 1-temporal_3_df
temporal_4_comparison = 1-temporal_4_df

# %%
from scipy.spatial.distance import squareform
import scipy
from scipy.spatial import distance as ssd

temporal_1_distance = 1-temporal_1_df
temporal_2_distance = 1-temporal_2_df
temporal_3_distance = 1-temporal_3_df
temporal_4_distance = 1-temporal_4_df

temporal_1_comparison = 1-temporal_1_df
temporal_2_comparison = 1-temporal_2_df
temporal_3_comparison = 1-temporal_3_df
temporal_4_comparison = 1-temporal_4_df

temporal_1_distance1 = np.array(temporal_1_comparison)
temporal_2_distance1 = np.array(temporal_2_comparison)
temporal_3_distance1 = np.array(temporal_3_comparison)
temporal_4_distance1 = np.array(temporal_4_comparison)

# %% [markdown]
# temporal_1_distance1 = np.array(temporal_1_comparison**temporal_1_comparison)
# temporal_2_distance1 = np.array(temporal_2_comparison**temporal_2_comparison)
# temporal_3_distance1 = np.array(temporal_3_comparison**temporal_3_comparison)
# temporal_4_distance1 = np.array(temporal_4_comparison**temporal_4_comparison)

# %%
temporal_1_distance1[temporal_1_distance1>.8]
# Out:
# array([0.89285714, 0.83168317, 0.90804598, 0.82222222, 0.81632653,
#        0.85492228, 0.82938389, 0.90804598, 0.8778626 , 0.81333333,
#        0.82938389, 0.84180791, 0.89565217, 0.88679245, 0.8778626 ,
#        0.80392157, 0.84090909, 0.95391705, 0.80310881, 0.91919192,
#        0.80099502, 0.90857143, 0.80373832, 0.86341463, 0.82954545,
#        0.85148515, 0.9078341 , 0.91919192, 0.83414634])

# %%
print(drugname)
#drugnamepath = drugname[:6]
print(temporal)
print(temporal_1)
print(spatial_list)
print(countofcountries)
temporal_1
k
# Out:
# xarelto
# year
# yr1
# ['at', 'be', 'ch', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie', 'it', 'nl', 'no', 'pl', 'se', 'si', 'tr']
# 19
# 5

# %% [markdown]
# xarelto
# year
# top 10 ['at', 'be', 'ch', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie', 'it', 'nl', 'no', 'pl', 'se', 'si', 'tr'] 19countries
# xarelto
# year
# yr1
# top5 ['at', 'be', 'ch', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie', 'it', 'nl', 'no', 'pl', 'se', 'si', 'tr']
# pradaxa
# top 10['at', 'be', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'it', 'nl', 'pl', 'pt', 'se']
# 13countries
# top 5 ['at', 'be', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie', 'it', 'nl', 'no', 'pl', 'pt', 'se', 'tr']
# 18 countries
#
# eliquis
# year
# yr1
# both top 5 and 10 ['at', 'de', 'es', 'fr', 'gb', 'gr', 'it', 'no', 'se']

# %%
temporal_1_comparison.index
# Out:
# Index(['at', 'be', 'ch', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie',
#        'it', 'nl', 'no', 'pl', 'se', 'si', 'tr'],
#       dtype='object')

# %%
temporallist = [temporal_1,temporal_2,temporal_3,temporal_4]
llist = [temporal_1_comparison,temporal_2_comparison,temporal_3_comparison,temporal_4_comparison]


#os.chdir(r"G:\Research\FAERS_Public\Results\Jaccard\tp10"+str('\\')+str(drugnamepath))
sns.set(font_scale=1, rc={'figure.figsize':(10,10)})

#sns.set(font_scale=3, rc={'figure.figsize':(50,50)})
plt.xticks(fontsize=10, rotation=90) #font size for x ticks
plt.yticks(fontsize=10) #font size for x ticks

plt.tick_params(labelsize=40)
for x,y in zip(llist,temporallist):
    number = y
    ax = sns.heatmap(x,annot=True, vmin=0, vmax=1)#change here for input

    ax.set_ylabel('FAERS (Jaccard Index Coefficent (Top 10 keywords)')
    ax.set_xlabel("FAERS (Jaccard Index Coefficent (Top 10 keywords), sptial: "+str(countofcountries)+" countires, Temporal: "+str(y)+" Drug: "+str(drugname))#change here
    for x in range(0,24):
    
        ax.add_patch(Rectangle((x, x), 1, 1, fill=False, edgecolor='#ffff00', lw=10))
        
    plt.title("Jaccard Index Coefficent (Top 10 frequent items)")#change here
   # plt.savefig("Jaccard_Similiarity_testing_"+str(countofcountries)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_top10_version_naive.png", dpi=300)

    
    

    #plt.show()
    plt.clf()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
temporal_1_mat = np.array([[temporal_1_distance1]])#lenalid_distance2
temporal_1_mat = temporal_1_mat.reshape(countofcountries, countofcountries)

temporal_2_mat = np.array([[temporal_2_distance1]])#lenalid_distance2
temporal_2_mat = temporal_2_mat.reshape(countofcountries, countofcountries)

temporal_3_mat = np.array([[temporal_3_distance1]])#lenalid_distance2
temporal_3_mat = temporal_3_mat.reshape(countofcountries, countofcountries)

temporal_4_mat = np.array([[temporal_4_distance1]])#lenalid_distance2
temporal_4_mat = temporal_4_mat.reshape(countofcountries, countofcountries)

# %%
import scipy.stats as ss
ss.friedmanchisquare(*temporal_3_matx.T)
#FriedmanchisquareResult(statistic=8.700000000000003, pvalue=0.03355726870553798)
label = temporal_1_comparison.index

# %%
import scikit_posthocs as sp
temporal_4_distance1_pvalue=sp.posthoc_ttest(temporal_4_mat,  p_adjust='holm-sidak')
temporal_4_distance1_pvalue
sns.set(font_scale=1, rc={'figure.figsize':(10,10)})

#sp.__convert_to_df(temporal_3_matx)
#sp.__convert_to_block_df(temporal_4_mat)
pc = sp.posthoc_ttest(temporal_4_mat, val_col='values', group_col='groups')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
#sp.sign_plot(pc, **heatmap_args)

# %%
# Format: diagonal, non-significant, p<0.001, p<0.01, p<0.05
sns.set(font_scale=1, rc={'figure.figsize':(10,10)})

cmap = ['1', '#fb6a4a',  '#08306b',  '#4292c6', '#c6dbef']
heatmap_args = {'cmap': cmap, 'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': True, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
#sp.sign_plot(pc, **heatmap_args)

# %% [markdown]
# #single
# #complete
# Z1 = linkage(temporal_1_mat, 'single')#LBNE_mat_distArray
# Z2 = linkage(temporal_2_mat, 'single')#LBNE_mat_distArray
# Z3 = linkage(temporal_3_mat, 'single')#LBNE_mat_distArray
# Z4 = linkage(temporal_4_mat, 'single')#LBNE_mat_distArray

# %%
#os.chdir(r"G:\Research\FAERS_Public\Results\Dendo\tp10"+str('\\')+str(drugnamepath))
os.chdir(r"H:\Research\FAERS_Public\dendo_ijgi")

import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage

#linkagemethod =['single','complete']
linkagemethod =['complete']

#complete


temporallist = [temporal_1,temporal_2,temporal_3,temporal_4]
llist = [temporal_1_distance1,temporal_2_distance1,temporal_3_distance1,temporal_4_distance1]
for lm in linkagemethod:
    
    for x,y in zip(llist,temporallist):
        plt.figure(figsize=(25, 15))
        plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=3)#, rc={'figure.figsize':(400,400)})

        number = y
        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[x]])#lenalid_distance2
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)#LBNE_mat_distArray





        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()
        #plt.axhline(y=0.3, c='grey', lw=1, linestyle='dashed')
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=35.,
            labels=temporal_1_df.index, count_sort=False, distance_sort=True,color_threshold=0.0 )#, color_threshold=0.212)#, color_threshold=0.3)#, color_threshold=0.02)

        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=30)#Change here

        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
        plt.box('off')

        #plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_version_naive.png", dpi=300)

        #plt.show()
        plt.clf()

# %%
#single
#complete
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
#os.chdir(r"G:\Research\FAERS_Public\Results\Dendo_plus_Jaccard\tp10"+str('\\')+str(drugnamepath))
os.chdir(r"H:\Research\FAERS_Public\dendo_jaccard_ijgi")

sns.set(font_scale=2, rc={'figure.figsize':(50,50)})

#single
#complete
#quarterlst1 = [q1_distance,q2_distance,q3_distance,q4_distance]
#llist = [q1_distance1,q2_distance1,q3_distance1,q4_distance1]
#llist = [y1_distance1,y2_distance1,y3_distance1,y4_distance1]

temporallistz = [temporal_1_distance,temporal_2_distance,temporal_3_distance,temporal_4_distance]
temporallist = [temporal_1,temporal_2,temporal_3,temporal_4]
llist = [temporal_1_distance1,temporal_2_distance1,temporal_3_distance1,temporal_4_distance1]
#linkagemethod =['single','complete']
linkagemethod =['complete']

#for lm in linkagemethod:
    
    #for x,y in zip(llist,temporallist):
for lm in linkagemethod:
    for x,y,z in zip(llist,temporallist,temporallistz):
        plt.figure(figsize=(25, 15))
        #plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=1.25)#, rc={'figure.figsize':(400,400)})

        number = y
        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[x]])#lenalid_distance2
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)

    #for x,y,z in zip(llist,range(1,5),quarterlst1):
        #sns.set(font_scale=1, rc={'figure.figsize':(200,200)})
        #number = y

        #year ='y'+str(number)+'_comparison'

        #_mat = np.array([[x]])#lenalid_distance2
        #_mat = _mat.reshape(14, 14)
        #Z = linkage(_mat, 'single')#LBNE_mat_distArray


        ax =sns.clustermap(z,  row_linkage=Z, col_linkage=Z)# change here
        plt.setp(ax.ax_heatmap.get_xticklabels(), rotation=45) # For x axis
        plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)

        #plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=10,  pad=20, x=10.3,)#Change here

       # plt.title("Hierarchical Clustering (Method = "+str(linkagemethod)+", Top 4 frequent items), count of countries: "+str(countofcountries)+" Drug: ",+str(drugname)+
               #   " temporal: "+str(y))
        plt.tight_layout()
    #    #plt.savefig("Dendrogram_Tree_plus_jaccard_FAERs_Similiarity_Top_4_frequent_items_19_countries_minsup_0dot01_"+year+".png", dpi=300, bbox_inches="tight")
       
        
       # plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.png", dpi=900, bbox_inches="tight")
        #plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.svg", dpi=900, bbox_inches="tight")
        #plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.pdf", dpi=900, bbox_inches="tight")

        #plt.show()
        plt.clf()
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# from scipy.cluster.hierarchy import linkage
#
# _1row_clusters_single = linkage(q1_distance1, method='single')#lenalid_distance2
# _2row_clusters_single = linkage(q2_distance1, method='single')
# _3row_clusters_single = linkage(q3_distance1, method='single')
# _4row_clusters_single = linkage(q4_distance1, method='single')
#
# from scipy.cluster.hierarchy import linkage
#
# _1row_clusters_complete = linkage(q1_distance1, method='complete')
# _2row_clusters_complete = linkage(q2_distance1, method='complete')#complete
# _3row_clusters_complete = linkage(q3_distance1, method='complete')
# _4row_clusters_complete = linkage(q4_distance1, method='complete')

# %%
from scipy.cluster.hierarchy import linkage

_1row_clusters_single = linkage(temporal_1_distance1, method='single')#lenalid_distance2
_2row_clusters_single = linkage(temporal_2_distance1, method='single')
_3row_clusters_single = linkage(temporal_3_distance1, method='single')
_4row_clusters_single = linkage(temporal_4_distance1, method='single')

from scipy.cluster.hierarchy import linkage

_1row_clusters_complete = linkage(temporal_1_distance1, method='complete')
_2row_clusters_complete = linkage(temporal_2_distance1, method='complete')#complete
_3row_clusters_complete = linkage(temporal_3_distance1, method='complete')
_4row_clusters_complete = linkage(temporal_4_distance1, method='complete')


#_1row_clusters_complete = linkage(temporal_1_distance1, method='average')
#_2row_clusters_complete = linkage(temporal_2_distance1, method='average')#complete
#_3row_clusters_complete = linkage(temporal_3_distance1, method='average')
#_4row_clusters_complete = linkage(temporal_4_distance1, method='average')

# %%
from scipy.cluster.hierarchy import fcluster
import pysal as ps 

#lenalid_distance = 1-lenalid_df
#bupreno_distance = 1-bupreno_df
#etanerc_distance = 1-etanerc_df
#nataliz_distance = 1-nataliz_df

#list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single,
 #       irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
#list2 = ['irow_clusters_single', 'terow_clusters_single', 'tirow_clusters_single', 'prow_clusters_single',
 #       'irow_clusters_complete', 'terow_clusters_complete', 'tirow_clusters_complete', 'prow_clusters_complete']


list1 = [_1row_clusters_single, _2row_clusters_single, _3row_clusters_single, _4row_clusters_single,
        _1row_clusters_complete, _2row_clusters_complete, _3row_clusters_complete, _4row_clusters_complete]
list2 = ['yr1row_clusters_single', 'yr2row_clusters_single', 'yr3row_clusters_single', 'yr4row_clusters_single',
        'yr1row_clusters_complete', 'yr2row_clusters_complete', 'yr3row_clusters_complete', 'yr4row_clusters_complete']

#list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]

#for x,x1 in zip(list1, list2):
 #   assignments = fcluster(x,0.1,'distance')  #0.45 e
    #labels=interfe_df.index###################################################
  #  labels=lenalid_df.index############################################################

#    print(set(assignments))
 #   print(str(x1))
  #  cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})


list2 = np.linspace(0.0, 1, num=50)

for y in list2:
        #for x in range(1,12):#new

    #print(x+str(y))
    assignments = fcluster(_1row_clusters_single, y,"distance")  #0.45 ey,'distance',y*nataliz_distance2.max()
   # labels=interfe_df.index#######################################################################change this one
    labels=temporal_1_df.index#######################################################################change this one

    #print('cluster cut off point= ', str(y))############
    #print(set(assignments))
    cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
   # mx = np.max(clusters_assignments)
   # mx = mx+1
   # print(mx-1, 'clusters')
#cluster_output['cluster1'] = (cluster_output['cluster'] ==1).astype(int)
#cluster_output['cluster2'] = (cluster_output['cluster'] ==2).astype(int)
#cluster_output['cluster3'] = (cluster_output['cluster'] ==3).astype(int)
#cluster_output['cluster4'] = (cluster_output['cluster'] ==4).astype(int)
#cluster_output['cluster5'] = (cluster_output['cluster'] ==5).astype(int)
#cluster_output['cluster6'] = (cluster_output['cluster'] ==6).astype(int)
#cluster_output['cluster7'] = (cluster_output['cluster'] ==7).astype(int)
#cluster_output['cluster8'] = (cluster_output['cluster'] ==8).astype(int)
#cluster_output['cluster9'] = (cluster_output['cluster'] ==9).astype(int)
#cluster_output['cluster10'] = (cluster_output['cluster'] ==10).astype(int)
#cluster_output['cluster11'] = (cluster_output['cluster'] ==11).astype(int)
#cluster_output['cluster12'] = (cluster_output['cluster'] ==12).astype(int)
#cluster_output['cluster13'] = (cluster_output['cluster'] ==13).astype(int)
#cluster_output['cluster14'] = (cluster_output['cluster'] ==14).astype(int)
#cluster_output['cluster15'] = (cluster_output['cluster'] ==15).astype(int)
#cluster_output['cluster16'] = (cluster_output['cluster'] ==16).astype(int)
#cluster_output['cluster17'] = (cluster_output['cluster'] ==17).astype(int)
#cluster_output['cluster18'] = (cluster_output['cluster'] ==18).astype(int)
#cluster_output['cluster19'] = (cluster_output['cluster'] ==19).astype(int)
#cluster_output['cluster20'] = (cluster_output['cluster'] ==20).astype(int)
#cluster_output['cluster21'] = (cluster_output['cluster'] ==21).astype(int)
#cluster_output['cluster22'] = (cluster_output['cluster'] ==22).astype(int)
#cluster_output['cluster23'] = (cluster_output['cluster'] ==23).astype(int)
#cluster_output['cluster24'] = (cluster_output['cluster'] ==24).astype(int)
#cluster_output['cluster25'] = (cluster_output['cluster'] ==25).astype(int)
#cluster_output['cluster26'] = (cluster_output['cluster'] ==26).astype(int)
#cluster_output['cluster27'] = (cluster_output['cluster'] ==27).astype(int)
#cluster_output['cluster28'] = (cluster_output['cluster'] ==28).astype(int)
#cluster_output['cluster29'] = (cluster_output['cluster'] ==29).astype(int)

#os.chdir(r"G:\Research\FAERS\Drug_Spatial\L_B_N_E\Data\Analysis_ready_data\Approri\summary_of_approri_dataset\spatial_auto\LBNE_method_single_complete_csv_cluster_at_different_cutoff")

#cluster_output.to_csv('spatial_auto_cutooff_0dot8_etanerc_method_single.csv')

#cluster_output
#clu = pd.get_dummies(cluster_output['cluster'])

# %%
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
#os.chdir(r"C:\Users\AhmedAskar\Desktop\FAERS_Public\Data\Helper_dataset\World")
#plt.title("Etanercept Hierarchical Clustering, method:single, (min sup=0.2, top (2) frequent items), cluster 4")

#world_shp = gpd.read_file(filename='world.shp')

#world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.strip()
#world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.lower()

#world_join = world_shp.merge(cluster_output, left_on='ISO_2DIGIT', right_on='occr_country', how='inner')
#cluster_output
#usstates_join = pd.concat([usstates_shp, cluster_output], ignore_index=True)
#columns = ['ObjectID', 'FIPS_CNTRY', 'GMI_CNTRY', 'ISO_2DIGIT', 'ISO_3DIGIT',
#       'ISO_NUM', 'CNTRY_NAME', 'LONG_NAME', 'ISOSHRTNAM', 'UNSHRTNAM',
 #      'LOCSHRTNAM', 'LOCLNGNAM', 'STATUS', 'POP2007', 'SQKM', 'SQMI',
 #      'LAND_SQKM', 'COLORMAP']
#world_join.drop(columns, axis=1, inplace=True)
#cb = world_join['cluster']
#usstates_join.to_csv('ttest.csv')
#sns.set(font_scale=1, rc={'figure.figsize':(200,200)})
os.chdir(r"D:\shapefiles\World")
#os.chdir(r"\\Fdswp03752\ocmgis_data\Scripts\Situation_Awareness_Natural_hazards\shapefiles\World")
#os.chdir(r"\\Fdswp03752\ocmgis_data\Scripts\Situation_Awareness_Natural_hazards\shapefiles\World")

world_shp = gpd.read_file(filename='world.shp')
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.strip()#ISOSHRTNAM
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.lower()
world_shp.head()
world_shp.ISO_2DIGIT
europe = ['AL', 'AD', 'AM', 'AT', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE',
        'DK', 'EE', 'ES', 'FO', 'FI', 'FR', 'GB', 'GE', 'GI', 'GR', 'HU', 'HR',
        'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MC', 'MK', 'MT', 'NO', 'NL', 'PL',
        'PT', 'RO', 'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'VA']
spatial_list = ["de","fr","gb","it","be","ch","es","nl","cz","se","gr","at","ie","pt","dk","no","sk","fi","hu"] # took out us, ca, pr, ru
world_shp2 = world_shp[world_shp['ISO_2DIGIT'].str.contains('|'.join(spatial_list),case=False, na=False, regex=True)]
world_shp1 = world_shp[world_shp['ISO_2DIGIT'].str.contains('|'.join(europe),case=False, na=False, regex=True)]
world_shp2['centroid'] = world_shp2['geometry'].centroid
world_shp2['coords'] = world_shp2['geometry'].apply(lambda x: x.representative_point().coords[:])
world_shp2['coords'] = [coords[0] for coords in world_shp2['coords']]
world_shp2['coords']

world_shp1['Lon'] = world_shp1.centroid.x
world_shp1['Lat'] = world_shp1.centroid.y

world_join = world_shp1.merge(cluster_output, left_on='ISO_2DIGIT', right_on='occr_country', how='inner')
#cluster_output
#usstates_join = pd.concat([usstates_shp, cluster_output], ignore_index=True)
columns = ['ObjectID', 'FIPS_CNTRY', 'GMI_CNTRY', 'ISO_2DIGIT', 'ISO_3DIGIT',
       'ISO_NUM', 'CNTRY_NAME', 'LONG_NAME', 'ISOSHRTNAM', 'UNSHRTNAM',
       'LOCSHRTNAM', 'LOCLNGNAM', 'STATUS', 'POP2007', 'SQKM', 'SQMI',
       'LAND_SQKM', 'COLORMAP']
world_join.drop(columns, axis=1, inplace=True)
cb = world_join['cluster']
#usstates_join.to_csv('ttest.csv')
sns.set(font_scale=1, rc={'figure.figsize':(200,200)})

world_join
temporal_1_df
labels
# Out:
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['at', 'be', 'ch', 'de', 'dk', 'es', 'fi', 'fr', 'gb', 'gr', 'hu', 'ie',
#        'it', 'nl', 'no', 'pl', 'se', 'si', 'tr'],
#       dtype='object')

# %% [markdown]
# from scipy.cluster.hierarchy import fcluster
# import pysal as ps
#
# #list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single]
#         #[irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
#
# #list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
# #list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]
# spatial_auto_dict ={}
# statespatial_auto001 =[]
# statespatial_auto05 =[]
# statespatial_auto01 =[]
# statespatial_auto001_dict ={}
# statespatial_auto05_dict ={}
# statespatial_auto01_dict ={}
# statespatial_auto001_count = ''
# statespatial_auto05_count = ''
# statespatial_auto01_count = ''
# p_values = []
# p_values_001 = []
# p_values_05 = []
# p_values_01 = []
# spatial_auto_dict ={}
# p_values = []
# clusters_assignments = []
# clusters_dicts = {}
# state = []
# cutoff = []
# #list2 = np.linspace(0.0, 2.5, num=51)
# list2 = np.linspace(0.0, 1, num=50)
#
# #list2 = np.linspace(0.0, 0.5, num=7)
# #str1 = ''.join(str(e) for e in list1)
# #for xx in list1:
# for y in list2:
#         #for x in range(1,12):#new
#
#     #print(x+str(y))
#     assignments = fcluster(_4row_clusters_complete,y,'distance')  #0.45 e
#    # labels=interfe_df.index#######################################################################change this one
#     labels=temporal_4_df.index#######################################################################change this one
#
#     cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
#     print(cluster_output)
#         #clusters_assignments.append(assignments)
#     print('cluster cut off point= ', str(y))############
#     #print(set(assignments))###########################################################################################
#     clusters_assignments = []
#     clusters_assignments.append(assignments)
#     mx = np.max(clusters_assignments)
#     mx = mx+1
#     print(mx)
#    # print(mx-1, 'clusters')############################################################################################
#         #clusters_assignments.append(assignments)
#     cutoff.append(y)
# #print('name of cluster =', str(str1))
#
#     for x in range(1,mx):
#         column = ('cluster' + str(x))
#         cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
#         cluster_output[column]
#         print('culumns=', str(x))
#         cb = cluster_output[column]#column

# %%
list1str = ['_1row_clusters_single', '_2row_clusters_single', '_3row_clusters_single', '_4row_clusters_single',
        '_1row_clusters_complete', '_2row_clusters_complete', '_3row_clusters_complete', '_4row_clusters_complete']
for x in list1str:
    print(x)
# Out:
# _1row_clusters_single
# _2row_clusters_single
# _3row_clusters_single
# _4row_clusters_single
# _1row_clusters_complete
# _2row_clusters_complete
# _3row_clusters_complete
# _4row_clusters_complete

# %% [markdown]
# from scipy.cluster.hierarchy import fcluster
# import pysal as ps
# from pysal.lib.weights import lat2W
# from pysal.explore.esda.moran import Moran
#
# from pysal.explore.esda.join_counts import Join_Counts
#
# cols = ['pvalue', 'countries','dendo_cluster','dendo_cutoff','temporal','temporal2']
# dat01 = pd.DataFrame(columns = cols)
# dat05 = pd.DataFrame(columns = cols)
# dat1 = pd.DataFrame(columns = cols)
#
#
# #list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single]
#         #[irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
# list1 = [_1row_clusters_single, _2row_clusters_single, _3row_clusters_single, _4row_clusters_single,
#         _1row_clusters_complete, _2row_clusters_complete, _3row_clusters_complete, _4row_clusters_complete]
# list1str = ['temporal_1_single', 'temporal_2_single', 'temporal_3_single', 'temporal_4_single',
#         'temporal_1_complete', 'temporal_2_complete', 'temporal_3_complete', 'temporal_4_complete']
# #list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
# #list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]
#
# spatial_auto_dict ={}
# statespatial_auto001 =[]
# statespatial_auto05 =[]
# statespatial_auto01 =[]
# statespatial_auto001_dict ={}
# statespatial_auto05_dict ={}
# statespatial_auto01_dict ={}
# statespatial_auto001_count = ''
# statespatial_auto05_count = ''
# statespatial_auto01_count = ''
# p_values = []
# p_values_001 = []
# p_values_05 = []
# p_values_01 = []
# spatial_auto_dict ={}
# p_values = []
# clusters_assignments = []
# clusters_dicts = {}
# state = []
# cutoff = []
# #list2 = np.linspace(0.0, 2.5, num=51)
# list2 = np.linspace(0.0, 1.2, num=60)
#
# #list2 = np.linspace(0.0, 0.5, num=7)
# #str1 = ''.join(str(e) for e in list1)
# #for xx in list1:
# for y,z in zip(list1,list1str):
#     for cut_off in list2:#new
#
#        # print(str(z))
#         assignments = fcluster(y,cut_off,'distance')  #0.45 e
#        # labels=interfe_df.index#######################################################################change this one
#         labels=temporal_4_df.index#######################################################################change this one
#
#         cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
#         #print(cluster_output)
#             #clusters_assignments.append(assignments)
#         #print('cluster cut off point= ', str(y))############
#         #print(set(assignments))###########################################################################################
#         clusters_assignments = []
#         clusters_assignments.append(assignments)
#         mx = np.max(clusters_assignments)
#         mx = mx+1
#         #print(mx)
#        # print(mx-1, 'clusters')############################################################################################
#             #clusters_assignments.append(assignments)
#         cutoff.append(y)
#     #print('name of cluster =', str(str1))
#
#         for x in range(1,mx):
#             column = ('cluster' + str(x))
#             cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
#             cluster_output[column]
#             #print('culumns=', str(x))
#             cb = cluster_output[column]#column
#            # w=ps.lat2W(countofcountries,1, rook=False)
#
#             w=lat2W(countofcountries,1, rook=False)
#
#             #jc=ps.Join_Counts(cb,w,permutations=999)
#
#             #jc=Join_Counts(cb,w,permutations=999)
#             jc=Moran(cb,w)
#             jc.bb
#             jc.bw
#             jc.ww
#             jc.J
#             len(jc.sim_bb)
#
#
#             p_values.append(jc.p_sim_bb)
#             #print(p_values)
#             cutoff.append(y)
#             cluster_output['p_values_'+str('for_cluster_column_')+str(x)] = jc.p_sim_bb
#             #sstate = cluster_output['STATE_ABBR']
#             #state.append(sstate)
#             #print(state)
#             #zero__dot_01_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01]
#             #zero__dot_05_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05]
#             #zero__dot_1_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1]
#             #print(zero__dot_01_pvalue,zero__dot_05_pvalue, zero__dot_1_pvalue)
#             #spatial_auto_dict = dict(zip(zero_dot_05_state, p_values))
#             #spatial_auto_dict = dict(zip(p_values, cluster_output['STATE_ABBR']))
#             if jc.p_sim_bb<0.01:
#                 #print('culumns=', str(x))
#                 print(jc.p_sim_bb, 'bb')
#                 print('very very very very significant__'*50)
#                 zero_dot_01_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_01_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01
#                 #print(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'])
#                 sstate_001 =  cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country']
#                 statespatial_auto001_count = sstate_001.shape[0]
#                 #print(statespatial_auto001_count)
#                 dat01 = dat01.append({'pvalue': str(jc.p_sim_bb), 'countries':str(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': str(statespatial_auto001_count), 'dendo_cutoff':str(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#             elif jc.p_sim_bb<0.05:
#                 #print('culumns=', str(x))
#                 #print('very significant__'*10)
#                 #print(jc.p_sim_bb, 'bb')
#                 zero_dot_05_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_05_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05
#                 #print(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'])
#                 sstate_05 =  cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country']
#                 statespatial_auto05_count = sstate_05.shape[0]
#                 #print(statespatial_auto05_count)
#                 dat05 = dat05.append({'pvalue': str(jc.p_sim_bb), 'countries':str(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': str(statespatial_auto05_count), 'dendo_cutoff':str(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#
#             elif jc.p_sim_bb<0.1:
#                 #print('culumns=', str(x))
#                 #print(jc.p_sim_bb, 'bb')
#                 #print('significant__'*10)
#                 zero_dot_1_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_1_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
#                 sstate_1 =  cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country']
#                 statespatial_auto1_count = sstate_1.shape[0]
#                 #print(statespatial_auto1_count)
#                 dat1 = dat1.append({'pvalue': str(jc.p_sim_bb), 'countries':str(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': str(statespatial_auto1_count), 'dendo_cutoff':str(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#
#            # elif jc.p_sim_bw<0.01:
#             #    print('culumns=', str(x))
#              #   print(jc.p_sim_bw, 'bw')
#               #  print('very very very very significant__'*50)
#                # print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])
#
#             #elif jc.p_sim_bw<0.05:
#              #   print('culumns=', str(x))
#               #  print('very significant__'*10)
#                # print(jc.p_sim_bw, 'bw')
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])
#
#             #elif jc.p_sim_bw<0.1:
#              #   print('culumns=', str(x))
#               #  print(jc.p_sim_bw, 'bw')
#                # print('significant__'*10)
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])
#
#                 #print('postive spatial autocorrelation=', jc.p_sim_bb)
#     #np.mean(jc.sim_bb)
#     #np.max(jc.sim_bb)
#     #np.min(jc.sim_bb)
#
#             len(jc.sim_bw)
#                 #print('negative spatial autocorrelation=',jc.p_sim_bw)
#     #np.mean(jc.sim_bw)
#     #np.max(jc.sim_bw)
#     #np.min(jc.sim_bw)
#
#                 #p_values
#
#
#             clusters_dicts =dict(zip(p_values, cluster_output['cluster']))
#     #row_count_itemset_dict = dict(zip(zero_dot_05_state, zero__dot_05_pvalue))

# %% [markdown]
# ## LISA Test
# http://pysal.org/notebooks/viz/splot/esda_morans_viz.html
# from pysal.explore.esda.moran import Moran
# from scipy.cluster.hierarchy import fcluster
# import pysal as ps
# from pysal.lib.weights import lat2W
# from pysal.explore.esda.moran import Moran, Moran_Local
#
# from pysal.explore.esda.join_counts import Join_Counts
#
# cols = ['pvalue', 'countries','dendo_cluster','dendo_cutoff','temporal','temporal2']
# dat01 = pd.DataFrame(columns = cols)
# dat05 = pd.DataFrame(columns = cols)
# dat1 = pd.DataFrame(columns = cols)
# datn = pd.DataFrame(columns = cols)
#
#
# #list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single]
#         #[irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
# list1 = [_1row_clusters_single, _2row_clusters_single, _3row_clusters_single, _4row_clusters_single,
#         _1row_clusters_complete, _2row_clusters_complete, _3row_clusters_complete, _4row_clusters_complete]
# list1str = ['temporal_1_single', 'temporal_2_single', 'temporal_3_single', 'temporal_4_single',
#         'temporal_1_complete', 'temporal_2_complete', 'temporal_3_complete', 'temporal_4_complete']
# #list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
# #list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]
#
# spatial_auto_dict ={}
# statespatial_auto001 =[]
# statespatial_auto05 =[]
# statespatial_auto01 =[]
# statespatial_auto =[]
#
# statespatial_auto001_dict ={}
# statespatial_auto05_dict ={}
# statespatial_auto01_dict ={}
# statespatial_auto_dict ={}
#
# statespatial_auto001_count = ''
# statespatial_auto05_count = ''
# statespatial_auto01_count = ''
# statespatial_auto_count = ''
#
# p_values = []
# p_values_ = []
# p_values_001 = []
# p_values_05 = []
# p_values_01 = []
#
# spatial_auto_dict ={}
# p_values = []
# clusters_assignments = []
# clusters_dicts = {}
# state = []
# cutoff = []
# #list2 = np.linspace(0.0, 2.5, num=51)
# #list2 = np.linspace(0.0, 1.2, num=60)
# list2 = np.linspace(0.0, 1.0, num=10)
#
#
# #list2 = np.linspace(0.0, 0.5, num=7)
# #str1 = ''.join(str(e) for e in list1)
# #for xx in list1:
# for y,z in zip(list1,list1str):
#     for cut_off in list2:#new
#
#        # print(str(z))
#         assignments = fcluster(y,cut_off,'distance')  #0.45 e
#        # labels=interfe_df.index#######################################################################change this one
#         labels=temporal_4_df.index#######################################################################change this one
#
#         cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
#         #print(cluster_output)
#             #clusters_assignments.append(assignments)
#         #print('cluster cut off point= ', str(y))############
#         #print(set(assignments))###########################################################################################
#         clusters_assignments = []
#         clusters_assignments.append(assignments)
#         mx = np.max(clusters_assignments)
#         mx = mx+1
#         #print(mx)
#        # print(mx-1, 'clusters')############################################################################################
#             #clusters_assignments.append(assignments)
#         cutoff.append(y)
#     #print('name of cluster =', str(str1))
#
#         for x in range(1,mx):
#             column = ('cluster' + str(x))
#             cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
#             cluster_output[column]
#             #print('culumns=', str(x))
#             cb = cluster_output[column]#column
#            # w=ps.lat2W(countofcountries,1, rook=False)
#
#             w=lat2W(countofcountries,1, rook=False)
#
#             #jc=ps.Join_Counts(cb,w,permutations=999)
#
#             #jc=Join_Counts(cb,w,permutations=999)
#             #jc=Moran(cb,w)
#             jc=Moran(cb,  w, two_tailed=True)
#             #jc=Moran_Local(cb,  w,transformation = "r", permutations = 99,geoda_quads=True)
#             #print(jc.p_z_sim)
#             #if jc.p_norm<=0.09:
#
#            #     print(jc.p_norm, 'jc')
#
#            # if tc.p_norm<=0.09:
#            #     print(tc.p_norm,'tc')
#            # else:
#            #     pass
#             p_values.append(jc.p_rand)
#             #print(p_values)
#             cutoff.append(y)
#             cluster_output['p_values_'+str('for_cluster_column_')+str(x)] = jc.p_rand
#             #sstate = cluster_output['STATE_ABBR']
#             #state.append(sstate)
#             #print(state)
#             #zero__dot_01_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01]
#             #zero__dot_05_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05]
#             #zero__dot_1_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1]
#             #print(zero__dot_01_pvalue,zero__dot_05_pvalue, zero__dot_1_pvalue)
#             #spatial_auto_dict = dict(zip(zero_dot_05_state, p_values))
#             #spatial_auto_dict = dict(zip(p_values, cluster_output['STATE_ABBR']))
#             if jc.p_rand<0.01:
#                 #print('culumns=', str(x))
#                 print(jc.p_norm, 'bb')
#                # print('very very very very significant__'*50)
#                 zero_dot_01_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_01_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01
#                 #print(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'])
#                 sstate_001 =  cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country']
#                 statespatial_auto001_count = sstate_001.shape[0]
#                 #print(statespatial_auto001_count)
#                 dat01 = dat01.append({'pvalue': str(jc.p_norm), 'countries':str(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto001_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#             elif jc.p_norm<0.05:
#                 #print('culumns=', str(x))
#                 #print('very significant__'*10)
#                 #print(jc.p_sim_bb, 'bb')
#                 zero_dot_05_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_05_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05
#                 #print(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'])
#                 sstate_05 =  cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country']
#                 statespatial_auto05_count = sstate_05.shape[0]
#                 #print(statespatial_auto05_count)
#                 dat05 = dat05.append({'pvalue': str(jc.p_norm), 'countries':str(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto05_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#
#             elif jc.p_norm<0.1:
#                 #print('culumns=', str(x))
#                 #print(jc.p_sim_bb, 'bb')
#                 #print('significant__'*10)
#                 zero_dot_1_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_1_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
#                 sstate_1 =  cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country']
#                 statespatial_auto1_count = sstate_1.shape[0]
#                 #print(statespatial_auto1_count)
#                 dat1 = dat1.append({'pvalue': str(jc.p_norm), 'countries':str(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto1_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#
#             elif jc.p_norm>=0.1:
#                 #print('culumns=', str(x))
#                 #print(jc.p_sim_bb, 'bb')
#                 #print('significant__'*10)
#                 zero_dot_n_state = cluster_output['cluster' + str(x)] == 1
#                 zero__dot_n_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] >=0.1
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
#                 sstate_n =  cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country']
#                 statespatial_auton_count = sstate_n.shape[0]
#                 #print(statespatial_auto1_count)
#                 datn = datn.append({'pvalue': str(jc.p_norm), 'countries':str(cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auton_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
#
#
#             #elif jc.p_sim_bw<0.05:
#              #   print('culumns=', str(x))
#               #  print('very significant__'*10)
#                # print(jc.p_sim_bw, 'bw')
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])
#
#             #elif jc.p_sim_bw<0.1:
#              #   print('culumns=', str(x))
#               #  print(jc.p_sim_bw, 'bw')
#                # print('significant__'*10)
#                 #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])
#
#                 #print('postive spatial autocorrelation=', jc.p_sim_bb)
#     #np.mean(jc.sim_bb)
#     #np.max(jc.sim_bb)
#     #np.min(jc.sim_bb)
#
#             #len(jc.sim_bw)
#                 #print('negative spatial autocorrelation=',jc.p_sim_bw)
#     #np.mean(jc.sim_bw)
#     #np.max(jc.sim_bw)
#     #np.min(jc.sim_bw)
#
#                 #p_values
#
#
#             clusters_dicts =dict(zip(p_values, cluster_output['cluster']))
#     #row_count_itemset_dict = dict(zip(zero_dot_05_state, zero__dot_05_pvalue))

# %% [markdown]
# countofcountries
# cluster_output
# w=lat2W(countofcountries,1, rook=False)
# w.neighbors
# w.weights
# cluster_output
# countofcountries
# w
# list1[0]
#
# cluster_output

# %%
#######################################3this one hideeeeeeeeeeeeeeeeeeeeeeee
from pysal.explore.esda.moran import Moran
from scipy.cluster.hierarchy import fcluster
import pysal as ps
from pysal.lib.weights import lat2W
from pysal.explore.esda.moran import Moran, Moran_Local

from pysal.explore.esda.join_counts import Join_Counts

cols = ['pvalue', 'zscore','moran_i' ,'countries','dendo_cluster','dendo_cutoff','temporal','temporal2']
dat01 = pd.DataFrame(columns = cols)
dat05 = pd.DataFrame(columns = cols)
dat1 = pd.DataFrame(columns = cols)
datn = pd.DataFrame(columns = cols)


#list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single]
        #[irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
list1 = [_1row_clusters_single, _2row_clusters_single, _3row_clusters_single, _4row_clusters_single,
        _1row_clusters_complete, _2row_clusters_complete, _3row_clusters_complete, _4row_clusters_complete]
list1str = ['temporal_1_single', 'temporal_2_single', 'temporal_3_single', 'temporal_4_single',
        'temporal_1_complete', 'temporal_2_complete', 'temporal_3_complete', 'temporal_4_complete']
#list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
#list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]

spatial_auto_dict ={}
statespatial_auto001 =[]
statespatial_auto05 =[]
statespatial_auto01 =[]
statespatial_auto =[]

statespatial_auto001_dict ={}
statespatial_auto05_dict ={}
statespatial_auto01_dict ={}
statespatial_auto_dict ={}

statespatial_auto001_count = ''
statespatial_auto05_count = ''
statespatial_auto01_count = ''
statespatial_auto_count = ''

morani = []
p_values = []
p_values_ = []
p_values_001 = []
p_values_05 = []
p_values_01 = []

z_values = []
z_values_ = []
z_values_001 = []
z_values_05 = []
z_values_01 = []

spatial_auto_dict ={}
p_values = []
clusters_assignments = []
clusters_dicts = {}
state = []
cutoff = []
#list2 = np.linspace(0.0, 2.5, num=51)
#list2 = np.linspace(0.0, 1.2, num=60)
list2 = np.linspace(0.0, 2.0, num=10)


#list2 = np.linspace(0.0, 0.5, num=7)
#str1 = ''.join(str(e) for e in list1)
#for xx in list1:
for y,z in zip(list1,list1str):
    for cut_off in list2:#new

       # print(str(z))
        assignments = fcluster(y,cut_off,'distance')  #0.45 e
       # labels=interfe_df.index#######################################################################change this one
        labels=temporal_4_df.index#######################################################################change this one

        cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
        #print(cluster_output)
            #clusters_assignments.append(assignments)
        #print('cluster cut off point= ', str(y))############
        #print(set(assignments))###########################################################################################
        clusters_assignments = []
        clusters_assignments.append(assignments)
        mx = np.max(clusters_assignments)
        mx = mx+1
        #print(mx)
       # print(mx-1, 'clusters')############################################################################################
            #clusters_assignments.append(assignments)
        cutoff.append(y)
    #print('name of cluster =', str(str1))

        for x in range(1,mx):
            column = ('cluster' + str(x))
            cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
            cluster_output[column]
            #print('culumns=', str(x))
           # cb = cluster_output[column]#column
#cluster_output
#cluster_output[column]
            #w=ps.lat2W(countofcountries,1, rook=False)
#w
#countofcountries
            world_join = world_shp1.merge(cluster_output, left_on='ISO_2DIGIT', right_on='occr_country', how='inner')
            cb = world_join[column]#column

#usstates_join = pd.concat([usstates_shp, cluster_output], ignore_index=True)
            #columns = ['ObjectID', 'FIPS_CNTRY', 'GMI_CNTRY', 'ISO_2DIGIT', 'ISO_3DIGIT',
            #   'ISO_NUM', 'CNTRY_NAME', 'LONG_NAME', 'ISOSHRTNAM', 'UNSHRTNAM',
            #   'LOCSHRTNAM', 'LOCLNGNAM', 'STATUS', 'POP2007', 'SQKM', 'SQMI',
             #  'LAND_SQKM', 'COLORMAP']
           # world_join.drop(columns, axis=1, inplace=True)
           # cb = world_join['cluster']
           # display(cb)
            w=lat2W(countofcountries,1, rook=False)
            
            #ps.queen_from_shapefile(world_join)
            #qW = ps.queen_from_shapefile(world_join)
#w
                       # w=lat2W(countofcountries,1, rook=False)

            #display(pd.DataFrame(*w.full()).astype(int))
            #jc=ps.Join_Counts(cb,w,permutations=999)
            #try: 
             #   print(w.neighbors[x])
            #except (KeyError):
             #       pass
            #jc=Join_Counts(cb,w,permutations=999)
            #jc=Moran(cb,w)
            jc=Moran(cb,  w, two_tailed=True,permutations = 999)
            p_values.append(jc.p_rand)
            z_values.append(jc.z_rand)
            morani.append(jc.I)

            #print(p_values)
            cutoff.append(y)
            cluster_output['p_values_'+str('for_cluster_column_')+str(x)] = jc.p_rand
            cluster_output['morani'+str('for_cluster_column_')+str(x)] = jc.I
            cluster_output['zscore'+str('for_cluster_column_')+str(x)] = jc.z_rand
            #sstate = cluster_output['STATE_ABBR']
            #state.append(sstate)
            #print(state)
            #zero__dot_01_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01]
            #zero__dot_05_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05]
            #zero__dot_1_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1]
            #print(zero__dot_01_pvalue,zero__dot_05_pvalue, zero__dot_1_pvalue)
            #spatial_auto_dict = dict(zip(zero_dot_05_state, p_values))
            #spatial_auto_dict = dict(zip(p_values, cluster_output['STATE_ABBR']))
            if jc.p_rand<0.01:
                #print('culumns=', str(x))
                #print(jc.p_norm, 'pvalue_norm <0.01')
               # print(jc.z_norm , 'zscore_norm <0.01')
                #print(jc.p_sim, 'pvalue_p_sim <0.01')

                #print(jc.p_z_sim, 'pvalue_z_sim <0.01')
                #print(jc.z_sim , 'zscore_z_sim <0.01')
                #print(jc.p_rand, 'pvalue_rand <0.01')
                #print(jc.z_rand , 'zscore_rand <0.01')
                #display(pd.DataFrame(*w.full()).astype(int))
                print(w.neighbors[x])
                #print(jc.I)
               # print('very very very very significant__'*50)
                zero_dot_01_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_01_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01
                
                #print(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'])
                sstate_001 =  cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country']  
                statespatial_auto001_count = sstate_001.shape[0]
                #print(statespatial_auto001_count)
                dat01 = dat01.append({'pvalue': float(jc.p_rand), 'zscore': float(jc.z_rand), 'moran_i': float(jc.I),
                                      'countries':str(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto001_count), 
                                      'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
            elif jc.p_rand<0.05:
                #print(jc.p_norm, 'pvalue_norm <0.05')
                #print(jc.z_norm , 'zscore_norm <0.05')
               # print(jc.p_sim, 'pvalue_p_sim <0.01')

               # print(jc.p_z_sim, 'pvalue_z_sim <0.05')
               # print(jc.z_sim , 'zscore_z_sim <0.05')
               # print(jc.p_rand, 'pvalue_rand <0.05')
                #print(jc.z_norm , 'zscore_rand <0.05')               
                #display(pd.DataFrame(*w.full()).astype(int))
                #print(w.neighbors[x])
               #print(jc.p_sim_bb, 'bb')
                zero_dot_05_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_05_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05
                #print(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'])
                sstate_05 =  cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country']  
                statespatial_auto05_count = sstate_05.shape[0]
                #print(statespatial_auto05_count)
                dat05 = dat05.append({'pvalue': float(jc.p_rand),'zscore': float(jc.z_rand),'moran_i': float(jc.I), 'countries':str(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto05_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)

            elif jc.p_rand<0.1:
                #print('culumns=', str(x))
                #print(jc.p_sim_bb, 'bb')
                #print('significant__'*10)
                zero_dot_1_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_1_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
                sstate_1 =  cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country']
                statespatial_auto1_count = sstate_1.shape[0]
                #print(statespatial_auto1_count)
                dat1 = dat1.append({'pvalue': float(jc.p_rand), 'zscore': float(jc.z_rand),'moran_i': float(jc.I),'countries':str(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto1_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
                #display(pd.DataFrame(*w.full()).astype(int))
            elif jc.p_rand>=0.1:
                #print('culumns=', str(x))
                #print(jc.p_sim_bb, 'bb')
                #print('significant__'*10)
                zero_dot_n_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_n_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] >=0.1
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
                sstate_n =  cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country']
                statespatial_auton_count = sstate_n.shape[0]
                #print(statespatial_auto1_count)
                datn = datn.append({'pvalue': float(jc.p_rand),'zscore': float(jc.z_rand),'moran_i': float(jc.I), 'countries':str(cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auton_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
                #display(pd.DataFrame(*w.full()).astype(int))

            #elif jc.p_sim_bw<0.05:
             #   print('culumns=', str(x))
              #  print('very significant__'*10)
               # print(jc.p_sim_bw, 'bw')
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])

            #elif jc.p_sim_bw<0.1:
             #   print('culumns=', str(x))
              #  print(jc.p_sim_bw, 'bw')
               # print('significant__'*10)
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])

                #print('postive spatial autocorrelation=', jc.p_sim_bb)
    #np.mean(jc.sim_bb)
    #np.max(jc.sim_bb)
    #np.min(jc.sim_bb)

            #len(jc.sim_bw)
                #print('negative spatial autocorrelation=',jc.p_sim_bw)
    #np.mean(jc.sim_bw)
    #np.max(jc.sim_bw)5
    #np.min(jc.sim_bw)

                #p_values


            clusters_dicts =dict(zip(p_values, cluster_output['cluster']))
    #row_count_itemset_dict = dict(zip(zero_dot_05_state, zero__dot_05_pvalue))
# Out:
# [0, 2]
# [2, 4]

# %%
from pysal.explore.esda.moran import Moran
from scipy.cluster.hierarchy import fcluster
import pysal as ps
from pysal.lib.weights import lat2W
from pysal.explore.esda.moran import Moran, Moran_Local

from pysal.explore.esda.join_counts import Join_Counts

cols = ['pvalue', 'zscore','moran_i' ,'countries','dendo_cluster','dendo_cutoff','temporal','temporal2']
dat01 = pd.DataFrame(columns = cols)
dat05 = pd.DataFrame(columns = cols)
dat1 = pd.DataFrame(columns = cols)
datn = pd.DataFrame(columns = cols)


#list1 = [irow_clusters_single, terow_clusters_single, tirow_clusters_single, prow_clusters_single]
        #[irow_clusters_complete, terow_clusters_complete, tirow_clusters_complete, prow_clusters_complete]
list1 = [_1row_clusters_single, _2row_clusters_single, _3row_clusters_single, _4row_clusters_single,
        _1row_clusters_complete, _2row_clusters_complete, _3row_clusters_complete, _4row_clusters_complete]
list1str = ['temporal_1_single', 'temporal_2_single', 'temporal_3_single', 'temporal_4_single',
        'temporal_1_complete', 'temporal_2_complete', 'temporal_3_complete', 'temporal_4_complete']
#list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
#list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]

spatial_auto_dict ={}
statespatial_auto001 =[]
statespatial_auto05 =[]
statespatial_auto01 =[]
statespatial_auto =[]

statespatial_auto001_dict ={}
statespatial_auto05_dict ={}
statespatial_auto01_dict ={}
statespatial_auto_dict ={}

statespatial_auto001_count = ''
statespatial_auto05_count = ''
statespatial_auto01_count = ''
statespatial_auto_count = ''

morani = []
p_values = []
p_values_ = []
p_values_001 = []
p_values_05 = []
p_values_01 = []

z_values = []
z_values_ = []
z_values_001 = []
z_values_05 = []
z_values_01 = []

spatial_auto_dict ={}
p_values = []
clusters_assignments = []
clusters_dicts = {}
state = []
cutoff = []
#list2 = np.linspace(0.0, 2.5, num=51)
#list2 = np.linspace(0.0, 1.2, num=60)
list2 = np.linspace(0.0, 2.0, num=10)


#list2 = np.linspace(0.0, 0.5, num=7)
#str1 = ''.join(str(e) for e in list1)
#for xx in list1:
for y,z in zip(list1,list1str):
    for cut_off in list2:#new

       # print(str(z))
        assignments = fcluster(y,cut_off,'distance')  #0.45 e
       # labels=interfe_df.index#######################################################################change this one
        labels=temporal_4_df.index#######################################################################change this one

        cluster_output = pd.DataFrame({'occr_country':labels , 'cluster':assignments})
        #print(cluster_output)
            #clusters_assignments.append(assignments)
        #print('cluster cut off point= ', str(y))############
        #print(set(assignments))###########################################################################################
        clusters_assignments = []
        clusters_assignments.append(assignments)
        mx = np.max(clusters_assignments)
        mx = mx+1
        #print(mx)
       # print(mx-1, 'clusters')############################################################################################
            #clusters_assignments.append(assignments)
        cutoff.append(y)
    #print('name of cluster =', str(str1))

        for x in range(1,mx):
            column = ('cluster' + str(x))
            cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
            cluster_output[column]
            #print('culumns=', str(x))
            cb = cluster_output[column]#column
           # w=ps.lat2W(countofcountries,1, rook=False)
           # world_join = world_shp1.merge(cluster_output, left_on='ISO_2DIGIT', right_on='occr_country', how='inner')
#cluster_output
#usstates_join = pd.concat([usstates_shp, cluster_output], ignore_index=True)
            #columns = ['ObjectID', 'FIPS_CNTRY', 'GMI_CNTRY', 'ISO_2DIGIT', 'ISO_3DIGIT',
            #   'ISO_NUM', 'CNTRY_NAME', 'LONG_NAME', 'ISOSHRTNAM', 'UNSHRTNAM',
            #   'LOCSHRTNAM', 'LOCLNGNAM', 'STATUS', 'POP2007', 'SQKM', 'SQMI',
             #  'LAND_SQKM', 'COLORMAP']
           # world_join.drop(columns, axis=1, inplace=True)
           # cb = world_join['cluster']
           # display(cb)
            w=lat2W(countofcountries,1, rook=False)
                       # w=lat2W(countofcountries,1, rook=False)

            #display(pd.DataFrame(*w.full()).astype(int))
            #jc=ps.Join_Counts(cb,w,permutations=999)
            #try: 
             #   print(w.neighbors[x])
            #except (KeyError):
             #       pass
            #jc=Join_Counts(cb,w,permutations=999)
            #jc=Moran(cb,w)
            jc=Moran(cb,  w, two_tailed=True,permutations = 999)
            #jc=Moran_Local(cb,  w,transformation = "r", permutations = 99,geoda_quads=True)
            #print(jc.p_z_sim)
            #if jc.p_norm<=0.09:
            
           #     print(jc.p_norm, 'jc')
                
           # if tc.p_norm<=0.09:
           #     print(tc.p_norm,'tc')
           # else:
           #     pass
            p_values.append(jc.p_rand)
            z_values.append(jc.z_rand)
            morani.append(jc.I)

            #print(p_values)
            cutoff.append(y)
            cluster_output['p_values_'+str('for_cluster_column_')+str(x)] = jc.p_rand
            cluster_output['morani'+str('for_cluster_column_')+str(x)] = jc.I
            cluster_output['zscore'+str('for_cluster_column_')+str(x)] = jc.z_rand
            #sstate = cluster_output['STATE_ABBR']
            #state.append(sstate)
            #print(state)
            #zero__dot_01_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01]
            #zero__dot_05_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05]
            #zero__dot_1_pvalue = cluster_output[cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1]
            #print(zero__dot_01_pvalue,zero__dot_05_pvalue, zero__dot_1_pvalue)
            #spatial_auto_dict = dict(zip(zero_dot_05_state, p_values))
            #spatial_auto_dict = dict(zip(p_values, cluster_output['STATE_ABBR']))
            if jc.p_rand<0.01:
                #print('culumns=', str(x))
                #print(jc.p_norm, 'pvalue_norm <0.01')
               # print(jc.z_norm , 'zscore_norm <0.01')
                #print(jc.p_sim, 'pvalue_p_sim <0.01')

                #print(jc.p_z_sim, 'pvalue_z_sim <0.01')
                #print(jc.z_sim , 'zscore_z_sim <0.01')
                #print(jc.p_rand, 'pvalue_rand <0.01')
               # print(jc.z_rand , 'zscore_rand <0.01')
                ##display(pd.DataFrame(*w.full()).astype(int))
                #print(w.neighbors[x])
                #print(jc.I)
               # print('very very very very significant__'*50)
                zero_dot_01_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_01_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.01
                
                #print(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'])
                sstate_001 =  cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country']  
                statespatial_auto001_count = sstate_001.shape[0]
                #print(statespatial_auto001_count)
                dat01 = dat01.append({'pvalue': float(jc.p_rand), 'zscore': float(jc.z_rand), 'moran_i': float(jc.I),
                                      'countries':str(cluster_output[zero_dot_01_state& zero__dot_01_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto001_count), 
                                      'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
            elif jc.p_rand<0.05:
                #print(jc.p_norm, 'pvalue_norm <0.05')
                #print(jc.z_norm , 'zscore_norm <0.05')
               # print(jc.p_sim, 'pvalue_p_sim <0.01')

               # print(jc.p_z_sim, 'pvalue_z_sim <0.05')
               # print(jc.z_sim , 'zscore_z_sim <0.05')
                #print(jc.p_rand, 'pvalue_rand <0.05')
               # print(jc.z_norm , 'zscore_rand <0.05')               
                #display(pd.DataFrame(*w.full()).astype(int))
                #print(w.neighbors[x])
               #print(jc.p_sim_bb, 'bb')
                zero_dot_05_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_05_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.05
                #print(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'])
                sstate_05 =  cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country']  
                statespatial_auto05_count = sstate_05.shape[0]
                #print(statespatial_auto05_count)
                dat05 = dat05.append({'pvalue': float(jc.p_rand),'zscore': float(jc.z_rand),'moran_i': float(jc.I), 'countries':str(cluster_output[zero_dot_05_state& zero__dot_05_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto05_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)

            elif jc.p_rand<0.1:
                #print('culumns=', str(x))
                #print(jc.p_sim_bb, 'bb')
                #print('significant__'*10)
                zero_dot_1_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_1_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] <0.1
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
                sstate_1 =  cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country']
                statespatial_auto1_count = sstate_1.shape[0]
                #print(statespatial_auto1_count)
                dat1 = dat1.append({'pvalue': float(jc.p_rand), 'zscore': float(jc.z_rand),'moran_i': float(jc.I),'countries':str(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auto1_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
                #display(pd.DataFrame(*w.full()).astype(int))
            elif jc.p_rand>=0.1:
                #print('culumns=', str(x))
                #print(jc.p_sim_bb, 'bb')
                #print('significant__'*10)
                zero_dot_n_state = cluster_output['cluster' + str(x)] == 1
                zero__dot_n_pvalue = cluster_output['p_values_'+str('for_cluster_column_')+str(x)] >=0.1
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['occr_country'])
                sstate_n =  cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country']
                statespatial_auton_count = sstate_n.shape[0]
                #print(statespatial_auto1_count)
                datn = datn.append({'pvalue': float(jc.p_rand),'zscore': float(jc.z_rand),'moran_i': float(jc.I), 'countries':str(cluster_output[zero_dot_n_state& zero__dot_n_pvalue]['occr_country'].str[-2:]), 'dendo_cluster': int(statespatial_auton_count), 'dendo_cutoff':float(cut_off), 'temporal': str(temporal),'temporal2': str(z)},ignore_index=True)
                #display(pd.DataFrame(*w.full()).astype(int))

            #elif jc.p_sim_bw<0.05:
             #   print('culumns=', str(x))
              #  print('very significant__'*10)
               # print(jc.p_sim_bw, 'bw')
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])

            #elif jc.p_sim_bw<0.1:
             #   print('culumns=', str(x))
              #  print(jc.p_sim_bw, 'bw')
               # print('significant__'*10)
                #print(cluster_output[zero_dot_1_state& zero__dot_1_pvalue]['STATE_ABBR'])

                #print('postive spatial autocorrelation=', jc.p_sim_bb)
    #np.mean(jc.sim_bb)
    #np.max(jc.sim_bb)
    #np.min(jc.sim_bb)

            #len(jc.sim_bw)
                #print('negative spatial autocorrelation=',jc.p_sim_bw)
    #np.mean(jc.sim_bw)
    #np.max(jc.sim_bw)5
    #np.min(jc.sim_bw)

                #p_values


            clusters_dicts =dict(zip(p_values, cluster_output['cluster']))
    #row_count_itemset_dict = dict(zip(zero_dot_05_state, zero__dot_05_pvalue))

# %% [markdown]
# from esda.moran import Moran
# from splot.esda import moran_scatterplot
# from splot.esda import plot_moran
#
# plot_moran(moran, zstandard=True, figsize=(10,4))
# plt.show()

# %%
countofcountries
w.histogram
Wmatrix, ids = w.full()
n_neighbors = Wmatrix.sum(axis=1)
n_neighbors[5]
w.cardinalities[3]
#Wmatrix.sum(axis=1)
#w.pct_nonzero
#w.id_order
#w.neighbors[17]
#w.sparse[0]
w.neighbors
#pd.DataFrame(*w.full()).astype(int)
#Wmatrix
#w.histogram
# Out:
# {0: [1],
#  1: [0, 2],
#  2: [1, 3],
#  3: [2, 4],
#  4: [3, 5],
#  5: [4, 6],
#  6: [5, 7],
#  7: [6, 8],
#  8: [7]}

# %% [markdown]
# t['countries'] = dat01['countries'].replace('\n',',', regex=True)
# t['countries'] = t['countries'].str.replace('\d+', '')
# #dat01['countries'].replace('\n',',', regex=True)
# t['countries']

# %%
datn
datn['countries'] = datn['countries'].replace('\n',',', regex=True)
datn['countries'] = datn['countries'].str.replace('\d+', '')
datn['countries'] = datn.countries.str[:-34]
datn['countries'] = datn.countries.str.strip()
datn = datn.drop_duplicates(subset=['countries','dendo_cluster'], keep='first')
datn = datn[(datn.dendo_cutoff>=0.1) & (datn.dendo_cluster>=2)]

len(datn.index)
# Out:
# 11

# %% [markdown]
# datn = datn[datn.dendo_cluster>=2& (datn.dendo_cutoff>=0.1)]#datn[datn['dendo_cluster']>2.0]
# datn
# datn = datn[(datn.dendo_cutoff>=0.1) & (datn.dendo_cluster>=2)]
# datn

# %%
dat01
dat01['countries'] = dat01['countries'].replace('\n',',', regex=True)
dat01['countries'] = dat01['countries'].str.replace('\d+', '')
dat01['countries'] = dat01.countries.str[:-34]
dat01['countries'] = dat01.countries.str.strip()
dat01 = dat01.drop_duplicates(subset=['countries','dendo_cluster'], keep='first')

dat01
# Out:
# Empty DataFrame
# Columns: [pvalue, zscore, moran_i, countries, dendo_cluster, dendo_cutoff, temporal, temporal2]
# Index: []

# %%
dat05
dat05['countries'] = dat05['countries'].replace('\n',',', regex=True)
dat05['countries'] = dat05['countries'].str.replace('\d+', '')

dat05['countries'] = dat05.countries.str[:-34]
dat05['countries'] = dat05.countries.str.strip()
dat05 = dat05.drop_duplicates(subset=['countries','dendo_cluster'], keep='first')
dat05
# Out:
# Empty DataFrame
# Columns: [pvalue, zscore, moran_i, countries, dendo_cluster, dendo_cutoff, temporal, temporal2]
# Index: []

# %%
dat1
dat1['countries'] = dat1['countries'].replace('\n',',', regex=True)
dat1['countries'] = dat1['countries'].str.replace('\d+', '')

dat1['countries'] = dat1.countries.str[:-34]
dat1['countries'] = dat1.countries.str.strip()
dat1 = dat1.drop_duplicates(subset=['countries','dendo_cluster'], keep='first')

dat1
# Out:
#      pvalue    zscore  moran_i                countries dendo_cluster  \
# 0  0.061497 -1.869903     -0.8  at,    es,    gr,    no             4
#
#    dendo_cutoff temporal          temporal2
# 0      1.111111     year  temporal_2_single

# %% [markdown]
# ### #Using complete linkage and positive autocorrelation only
# except for top 2 quarter single linkage

# %%
frame = [datn,dat1,dat05,dat01]
dat = pd.concat(frame)
dat = dat[dat['dendo_cluster']>1]

# %%
dat
# Out:
#        pvalue    zscore       moran_i                              countries  \
# 36   0.599314 -0.525387 -2.857143e-01                              es,    gb
# 44   0.781763 -0.277023 -2.250000e-01         at,    es,    fr,    gb,    it
# 145  0.599314 -0.525387 -2.857143e-01                              fr,    it
# 248  0.367948  0.900324  2.000000e-01                at,    es,    fr,    gb
# 252  0.447917 -0.758893 -3.571429e-01                              gr,    no
# 253  0.119097 -1.558576 -6.666667e-01  at,    es,    fr,    gb,    it,    se
# 305  0.401339 -0.839233 -4.166667e-01                       gb,    it,    se
# 306  0.729134 -0.346278 -2.500000e-01         at,    de,    es,    gr,    no
# 355  0.599314 -0.525387 -2.857143e-01                              at,    no
# 360  0.719093  0.359671  2.775558e-17                       fr,    gb,    it
# 417  0.533087  0.623301  1.000000e-01         at,    de,    gr,    no,    se
# 0    0.061497 -1.869903 -8.000000e-01                at,    es,    gr,    no
#
#     dendo_cluster  dendo_cutoff temporal            temporal2
# 36              2      0.888889     year    temporal_1_single
# 44              5      1.111111     year    temporal_1_single
# 145             2      1.111111     year    temporal_3_single
# 248             4      1.111111     year  temporal_1_complete
# 252             2      1.333333     year  temporal_1_complete
# 253             6      1.333333     year  temporal_1_complete
# 305             3      1.333333     year  temporal_2_complete
# 306             5      1.333333     year  temporal_2_complete
# 355             2      1.111111     year  temporal_3_complete
# 360             3      1.333333     year  temporal_3_complete
# 417             5      1.333333     year  temporal_4_complete
# 0               4      1.111111     year    temporal_2_single

# %%
#Using complete linkage and positive autocorrelation only

#frame = [datn,dat1,dat05,dat01]
#dat = pd.concat(frame)

dat.pvalue = dat.pvalue.astype(float)
dat['pvalue']=dat['pvalue'].round(decimals=5)
#dat[dat['pvalue']<=.05]

dat
os.chdir(r"H:\Research\FAERS_Public\p_value_ijgi_v2")
#dat.to_csv('spatial_autocorrelation_test.csv')
dat[dat['pvalue']<=.05]
# Out:
# Empty DataFrame
# Columns: [pvalue, zscore, moran_i, countries, dendo_cluster, dendo_cutoff, temporal, temporal2]
# Index: []

# %%
print('k is ', k)
stop
dat
# Out:
# k is  5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-253-6967c6af8970> in <module>
#       1 print('k is ', k)
# ----> 2 stop
#       3 dat
#
# NameError: name 'stop' is not defined

# %%
pwd

# %%
os.chdir(r"H:\Research\FAERS_Public\p_value_ijgi_v2")

dat.to_csv('spatial_autocorrelation_test_'+str(drugname)+'_'+str(temporal)+'_top_'+str(kk)+'_'+str(countofcountries)+'countofcountries_version_moran_freq_20200908.csv')

# %% [markdown]
# dat.loc[(dat['dendo_cluster'] == 10), ["pvalue"]] = 0.099087
# #dat.loc[(dat['countries'] == 'nl,    no'), ["pvalue"]] = 0.01795
# dat[dat['pvalue']<=.05]

# %%
len(spatial_list)
version = 'v1'

# %%
dat_=dat[dat.temporal2=='temporal_3_complete'] 

p_val_ = 0.01181
#cutoffval = dat.loc[dat['pvalue'] == 3, 'A']
dat_ =dat_[dat_.pvalue==p_val_]
cutoffval = dat_.loc[dat_.pvalue==p_val_,'dendo_cutoff']
pvalue = dat_[dat_.pvalue==p_val_]
te_num = dat_.temporal2.iloc[0][9:10]
te_num =int(te_num)
print(te_num)
#dat_ = dat_.iloc[0]
dat_ =dat_.head(1)
#dat_ =dat_.tail(1)

dat_

# %%
#spatial_list = [temporal_1_.spatial,temporal_2_.spatial,temporal_3_.spatial,temporal_4_.spatial]

#for x in spatial_list:
 #   print(x)
spatial_list= temporal_4_.spatial.tolist()
print(len(spatial_list))
#temporal_2_['FaersValue'].iloc[7]
#temporal_3_

# %%
dat_['countries'] = dat_['countries'].str.strip()
dat_['countries'] = dat_['countries'].str.strip()
#Faers_comparision['FaersValue'] = Faers_comparision['FaersValue'].str.lower()
dat_['countries'] = dat_['countries'].str.replace(u"/",",")
dat_['countries'] = dat_['countries'].str.replace(u"\\\\", ",")

dat_['countries'] = dat_['countries'].str.replace(u"' ","'")

dat_['countries'] = dat_['countries'].str.replace('\n',"")
dat_['countries'] = dat_['countries'].str.replace(' \n',"")
dat_['countries'] = dat_['countries'].str.replace('\n ',"")

dat_['countries'] = [''.join(c.split()) for c in dat_['countries'].astype(str)]

dat_['countries'] = dat_['countries'].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r"\n",  '', regex=True)
dat_['countries'] = dat_['countries'].str.replace(r"[\"\']", '')
dat_['countries'] = dat_['countries'].str.replace(',,,',',')
dat_['countries'] = dat_['countries'].str.replace(',,',',')
dat_['countries'] = dat_['countries'].str.replace('{','')
dat_['countries'] = dat_['countries'].str.replace('','')

#dat05['countries'] = dat05['countries'].str[1:]
#dat05['countries'] = dat05['countries'].str[:-1]
test = dat_['countries']
spatial_country_check = []
for x in test:
    spatial_country_check.append(x)
spatial_country_check
pattern = [item.replace(",", "|") for item in spatial_country_check]
pattern =pattern[-1]
for x in [te_num]:
    if (x) == 3:
        tempdf = temporal_3_[temporal_3_['spatial'].str.contains(pattern)]
    if (x) == 2:
        tempdf = temporal_2_[temporal_2_['spatial'].str.contains(pattern)]
    if (x) == 1:
        tempdf = temporal_1_[temporal_1_['spatial'].str.contains(pattern)]
    if (x) == 4:
        tempdf = temporal_4_[temporal_4_['spatial'].str.contains(pattern)]
#tempdf['pvalue']=np.float
#tempdf = temporal_2_[temporal_2_['spatial'].str.contains(pattern)]


tempdf

# %%
pval = pvalue['pvalue'].values
pval = str(pval)
tempdf['pvalue']=pval
cutoffval = pvalue['dendo_cutoff'].values[0]
cutoffval = float(cutoffval)
tempdf['cutoff']=cutoffval
tempdf['cutoff'] =round(tempdf['cutoff'],3)
tempdf

# %% [markdown]
# #temporal_2_[spatial]=temporal_2_[spatial].strip()
# tempdf = temporal_2_[temporal_2_['spatial'].str.contains('be|ch|cz|de|dk|es|fr|gb|gr|ie|it|pt|se|tr')]
# tempdf

# %%
#os.chdir(r"\\Fdswp03752\ocmgis_data\Scripts\Situation_Awareness_Natural_hazards\shapefiles\World")
os.chdir(r"D:\shapefiles\World")
world_shp = gpd.read_file(filename='world.shp')
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.strip()#ISOSHRTNAM
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.lower()
world_shp['CNTRY_NAME'] = world_shp['CNTRY_NAME'].str.strip()#ISOSHRTNAM
world_shp['CNTRY_NAME'] = world_shp['CNTRY_NAME'].str.lower()

world_shp.head()
world_shp.ISO_2DIGIT
europe = ['AL', 'AD', 'AM', 'AT', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE',
        'DK', 'EE', 'ES', 'FO', 'FI', 'FR', 'GB', 'GE', 'GI', 'GR', 'HU', 'HR',
        'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MC', 'MK', 'MT', 'NO', 'NL', 'PL',
        'PT', 'RO', 'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'VA']

world_shp1 = world_shp[world_shp['ISO_2DIGIT'].str.contains('|'.join(europe),case=False, na=False, regex=True)]

world_shp1['centroid'] = world_shp1['geometry'].centroid
world_shp1['coords'] = world_shp1['geometry'].apply(lambda x: x.representative_point().coords[:])
world_shp1['coords'] = [coords[0] for coords in world_shp1['coords']]
world_shp1['coords']

world_shp1['Lon'] = world_shp1.centroid.x
world_shp1['Lat'] = world_shp1.centroid.y

world_shp1
tempdf = pd.merge(tempdf,
                 world_shp1[['ISO_2DIGIT', 'CNTRY_NAME']],
                  left_on='spatial',
                  right_on='ISO_2DIGIT',
                  how='left')
tempdf


#tempdf['FaersValuev2'] = (tempdf['FaersValue'].str.split(', ').apply(lambda x: OrderedDict.fromkeys(x).keys()).str.join(', '))

# %%
len(tempdf.index)

# %%
from collections import Counter
count  = tempdf['FaersValue'].str.split(', ').map(Counter).sum()
c= pd.DataFrame(list(count.items()), columns=['PT', 'Overall_PT_Count_country'])
c.PT=c.PT.str.strip()
#c =c[c.Overall_PT_Count_country>=0]

maptext =c[c.Overall_PT_Count_country>=0]
space = []
clus_count = []
for index, row in maptext.PT.iteritems():
    #print(index,row)
    val = maptext.PT.loc[index]
    space1 = tempdf[tempdf.FaersValue.str.contains(val, na=False, regex=True)]
    space1 = space1.CNTRY_NAME
    space.append(space1.tolist())
maptext['CountryPT_in_Cluster']=space
maptext = maptext.reset_index(drop=True)
for index, row in maptext.CountryPT_in_Cluster.iteritems():
    y = len(maptext['CountryPT_in_Cluster'].iloc[index])
    clus_count.append(y)
maptext['CountryPT_in_Cluster_count']=clus_count
    
maptext['percent_in_cluster']=round(maptext['CountryPT_in_Cluster_count']/maptext.Overall_PT_Count_country,3)*100
c = maptext
maptext =maptext[maptext.CountryPT_in_Cluster_count>=2]

maptext

# %%
c

# %%
cutoff = tempdf.cutoff[0]
pval =tempdf.pvalue[0]
tempor = tempdf.temporal[0]
count_countries = len(tempdf.index)
print('cutoff=', cutoff)
print('pval=',pval)
print('tempor=',tempor)
print('count_countries=',count_countries)
print('drugname=',drugname)

lm= dat_.temporal2.iloc[0][11:]

# %%
str(temporal[0::3])

# %%
te_num
lm = str(dat_.temporal2.iloc[0][11:])

# %%
#os.chdir(r"G:\Research\FAERS_Public\Results\Dendo\tp10"+str('\\')+str(drugnamepath))
os.chdir(r"H:\Research\FAERS_Public\dendo_ijgi\20200908")
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage

linkagemethod =['single','complete']
#complete

plt.figure(figsize=(25, 15))
plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
sns.set(font_scale=3)#, rc={'figure.figsize':(400,400)})

temporallist = [temporal_1,temporal_2,temporal_3,temporal_4]
llist = [temporal_1_distance1,temporal_2_distance1,temporal_3_distance1,temporal_4_distance1]
#for lm in linkagemethod:
 #   if lm == dat.temporal2.iloc[0][11:]:
   #     lm == dat.temporal2.iloc[0][11:]
print(lm)
        
for x in [te_num]:
    if (x) == 3:
        number = temporal_3
        _mat = np.array([[temporal_3_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)
        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()
        #plt.axhline(y=0.3, c='grey', lw=1, linestyle='dashed')
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=35.,
            labels=temporal_1_df.index, count_sort=False, distance_sort=True,color_threshold=cutoff )#, color_threshold=0.212)#, color_threshold=0.3)#, color_threshold=0.02)

        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
        plt.box('off')

        plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=300)

        #plt.show()
        #plt.clf()

    if (x) == 2:
        number = temporal_2
        _mat = np.array([[temporal_2_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)
        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()
        #plt.axhline(y=0.3, c='grey', lw=1, linestyle='dashed')
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=35.,
            labels=temporal_1_df.index, count_sort=False, distance_sort=True,color_threshold=cutoff )#, color_threshold=0.212)#, color_threshold=0.3)#, color_threshold=0.02)

        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
        plt.box('off')

        plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=300)

        #plt.show()
        #plt.clf()
    if (x) == 1:
        number = temporal_1
        _mat = np.array([[temporal_1_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)
        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()
        #plt.axhline(y=0.3, c='grey', lw=1, linestyle='dashed')
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=35.,
            labels=temporal_1_df.index, count_sort=False, distance_sort=True,color_threshold=cutoff )#, color_threshold=0.212)#, color_threshold=0.3)#, color_threshold=0.02)

        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
        plt.box('off')

        plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=300)

        #plt.show()
        #plt.clf()
    if (x) == 4:
        number = temporal_4
        _mat = np.array([[temporal_4_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)
        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()
        #plt.axhline(y=0.3, c='grey', lw=1, linestyle='dashed')
        dendrogram(
            Z,
            leaf_rotation=90.,  # rotates the x axis labels
            leaf_font_size=35.,
            labels=temporal_1_df.index, count_sort=False, distance_sort=True,color_threshold=cutoff )#, color_threshold=0.212)#, color_threshold=0.3)#, color_threshold=0.02)

        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
        plt.box('off')

    plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=300)

            #plt.show()
            #plt.clf()
        #tempdf['pvalue']=np.float
    #tempdf = temporal_2_[temporal_2_['spatial'].str.contains(pattern)]


plt.show()

# %%
#single
#complete
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
#os.chdir(r"G:\Research\FAERS_Public\Results\Dendo_plus_Jaccard\tp10"+str('\\')+str(drugnamepath))
os.chdir(r"H:\Research\FAERS_Public\dendo_jaccard_ijgi\20200908")

sns.set(font_scale=2, rc={'figure.figsize':(50,50)})


import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage

linkagemethod =['single','complete']
#complete

sns.set(font_scale=2, rc={'figure.figsize':(50,50)})

temporallistz = [temporal_1_distance,temporal_2_distance,temporal_3_distance,temporal_4_distance]
temporallist = [temporal_1,temporal_2,temporal_3,temporal_4]
llist = [temporal_1_distance1,temporal_2_distance1,temporal_3_distance1,temporal_4_distance1]
#linkagemethod =['single','complete']

#for lm in linkagemethod:
  #  if lm == dat.temporal2.iloc[0][11:]:
    #    lm == dat.temporal2.iloc[0][11:]
print(lm)


for x in [te_num]:
    if (x) == 3:
        number = temporal_3
        plt.figure(figsize=(25, 15))
        #plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=1.25)#, rc={'figure.figsize':(400,400)})

        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[temporal_3_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)

        ax =sns.clustermap(temporal_3_distance,  row_linkage=Z, col_linkage=Z)# change here
        plt.setp(ax.ax_heatmap.get_xticklabels(), rotation=45) # For x axis
        plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)

        #plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=10,  pad=20, x=10.3,)#Change here

       # plt.title("Hierarchical Clustering (Method = "+str(linkagemethod)+", Top 4 frequent items), count of countries: "+str(countofcountries)+" Drug: ",+str(drugname)+
               #   " temporal: "+str(y))
        plt.tight_layout()

        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()

    #        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

    #        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
    #        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
    #       plt.box('off')
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".svg", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".pdf", dpi=900, bbox_inches="tight")

    #        plt.savefig("Dendrogram_Tree_cluster_linkage_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+"_version_naive.png", dpi=300)

        #plt.show()
        #plt.clf()

    if (x) == 2:
        number = temporal_2
        plt.figure(figsize=(25, 15))
        #plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=1.25)#, rc={'figure.figsize':(400,400)})

        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[temporal_2_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)

        ax =sns.clustermap(temporal_2_distance,  row_linkage=Z, col_linkage=Z)# change here
        plt.setp(ax.ax_heatmap.get_xticklabels(), rotation=45) # For x axis
        plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)

        #plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=10,  pad=20, x=10.3,)#Change here

       # plt.title("Hierarchical Clustering (Method = "+str(linkagemethod)+", Top 4 frequent items), count of countries: "+str(countofcountries)+" Drug: ",+str(drugname)+
               #   " temporal: "+str(y))
        plt.tight_layout()

        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()

    #        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

    #        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
    #        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
    #       plt.box('off')
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".svg", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".pdf", dpi=900, bbox_inches="tight")

        #plt.show()
        #plt.clf()
    if (x) == 1:
        number = temporal_1
        plt.figure(figsize=(25, 15))
        #plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=1.25)#, rc={'figure.figsize':(400,400)})

        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[temporal_1_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)

        ax =sns.clustermap(temporal_1_distance,  row_linkage=Z, col_linkage=Z)# change here
        plt.setp(ax.ax_heatmap.get_xticklabels(), rotation=45) # For x axis
        plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)

        #plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=10,  pad=20, x=10.3,)#Change here

       # plt.title("Hierarchical Clustering (Method = "+str(linkagemethod)+", Top 4 frequent items), count of countries: "+str(countofcountries)+" Drug: ",+str(drugname)+
               #   " temporal: "+str(y))
        plt.tight_layout()

        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()

    #        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

    #        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
    #        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
    #       plt.box('off')
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".svg", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".pdf", dpi=900, bbox_inches="tight")

        #plt.show()
        #plt.clf()
    if (x) == 4:
        number = temporal_4
        plt.figure(figsize=(25, 15))
        #plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
        sns.set(font_scale=1.25)#, rc={'figure.figsize':(400,400)})

        #year ='y'+str(number)+'_comparison'
        #print(year)    
        #quarter ='q'+str(number)+'_comparison'
       # print(quarter)
        _mat = np.array([[temporal_4_distance1]])
        _mat = _mat.reshape(countofcountries, countofcountries)
        Z = linkage(_mat, lm)

        ax =sns.clustermap(temporal_4_distance,  row_linkage=Z, col_linkage=Z)# change here
        plt.setp(ax.ax_heatmap.get_xticklabels(), rotation=45) # For x axis
        plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)

        #plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(y), fontsize=10,  pad=20, x=10.3,)#Change here

       # plt.title("Hierarchical Clustering (Method = "+str(linkagemethod)+", Top 4 frequent items), count of countries: "+str(countofcountries)+" Drug: ",+str(drugname)+
               #   " temporal: "+str(y))
        plt.tight_layout()

        plt.xticks(fontsize=5, rotation=90) #font size for x ticks
        plt.tight_layout()

    #        plt.title("Hierarchical Cluster Analysis (Linkage Method = "+str(lm)+", Top "+str(kk)+" frequent items), Pharmaceutical Drug: "+str(drugname)+", Temporal: "+str(te_num), fontsize=30)#Change here

    #        #plt.ylabel('Similiarity between ' +str(countofcountries)+' European Countries using FAERS Post Market Adverse Events', fontsize=20)#Change here
    #        plt.ylabel('Similiarity Inverse Distances from Jaccard Coefficients', fontsize=20)
    #       plt.box('off')
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".svg", dpi=900, bbox_inches="tight")
        plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".pdf", dpi=900, bbox_inches="tight")

            #plt.clf()
    #tempdf['pvalue']=np.float
#tempdf = temporal_2_[temporal_2_['spatial'].str.contains(pattern)]


plt.show()

# %%
os.chdir(r"H:\Research\FAERS_Public\shared_AE\20200908")
#dat.to_csv('spatial_autocorrelation_test_'+str(drugname)+'_'+str(temporal)+'_'+str(cutoff)+'_'+str(pval)+'_'+str(tempor)+'_'+str(countofcountries)+'countofcountries_version_naive.csv')
tempdf.to_csv("faersVaues_"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+"_20200906.csv")
c.to_csv('shared_maptext_'+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+"_20200906.csv")

# %%
prev_result =dat_[['countries']]
prev_result

# %%
prev_result2 = pd.DataFrame(prev_result.countries.str.split(',').tolist())
prev_result2 = prev_result2.T
prev_result2['cluster']=0
prev_result2.columns.values[0] = "occr_country"

prev_result2

# %%
#importing modules
import os 
print('importing "os" operating system')
from io import BytesIO
#from urllib.request import urlopen
from zipfile import ZipFile
import pandas as pd
print('pandas')
import geopandas as gpd
print('geopandas')
from shapely.geometry import Point
print('shapely')
import numpy as np
print('numpy')
from statsmodels.tsa.stattools import grangercausalitytests
print('statsmodels')
import pysal as ps
print('pysal')
import seaborn as sns
print('seaborn')
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
print('matplotlib')


# %matplotlib inline
import os
import pandas as pd

# %%
os.chdir(r"D:\shapefiles\World")
world_shp = gpd.read_file(filename='world.shp')
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.strip()#ISOSHRTNAM
world_shp['ISO_2DIGIT'] = world_shp['ISO_2DIGIT'].str.lower()
world_shp.head()
world_shp.ISO_2DIGIT
europe = ['AL', 'AD', 'AM', 'AT', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE',
        'DK', 'EE', 'ES', 'FO', 'FI', 'FR', 'GB', 'GE', 'GI', 'GR', 'HU', 'HR',
        'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MC', 'MK', 'MT', 'NO', 'NL', 'PL',
        'PT', 'RO', 'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'VA']
#spatial_list = ["de","fr","gb","it","be","ch","es","nl","cz","se","gr","at","ie","pt","dk","no","sk","fi","hu"] # took out us, ca, pr, ru
world_shp2 = world_shp[world_shp['ISO_2DIGIT'].str.contains('|'.join(spatial_list),case=False, na=False, regex=True)]
world_shp1 = world_shp[world_shp['ISO_2DIGIT'].str.contains('|'.join(europe),case=False, na=False, regex=True)]
world_shp2['centroid'] = world_shp2['geometry'].centroid
world_shp2['coords'] = world_shp2['geometry'].apply(lambda x: x.representative_point().coords[:])
world_shp2['coords'] = [coords[0] for coords in world_shp2['coords']]
world_shp2['coords']
world_shp1['centroid'] = world_shp1['geometry'].centroid
world_shp1['coords'] = world_shp1['geometry'].apply(lambda x: x.representative_point().coords[:])
world_shp1['coords'] = [coords[0] for coords in world_shp1['coords']]
world_shp1['coords']

world_shp1['Lon'] = world_shp1.centroid.x
world_shp1['Lat'] = world_shp1.centroid.y

alleurope1=world_shp1
someeurope=world_shp2

# %%
alleurope1.ISO_2DIGIT = alleurope1.ISO_2DIGIT.str.strip()
prev_result2.occr_country = prev_result2.occr_country.str.strip()
world_join = alleurope1.merge(prev_result2 , left_on='ISO_2DIGIT', right_on='occr_country', how='outer')
world_join = world_join[~world_join["occr_country"].isnull()]
world_join

# %%
Products_list = [maptext.columns.values.tolist()]+ maptext[['PT','CountryPT_in_Cluster_count','CountryPT_in_Cluster','percent_in_cluster']].values.tolist()
#Products_list = maptext[['PT','CountryPT_in_Cluster_count','CountryPT_in_Cluster','percent_in_cluster']].values.tolist()

f = '{:}|{:}|{:}|{:}\n' # formatting
text1_statecount=[]
for i in Products_list:
    text1_statecount.append(f.format(*i,'\n'))
    print(f.format(*i))

# %%
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
#os.chdir(r"G:\Research\FAERS\Drug_Spatial\L_B_N_E\Data\Helper_Datasets\shapefiles\USstates")
#plt.title("Etanercept Hierarchical Clustering, method:single, (min sup=0.2, top (2) frequent items), cluster 4")

someeurope.ISO_2DIGIT = someeurope.ISO_2DIGIT.str.strip()
prev_result2.occr_country = prev_result2.occr_country.str.strip()
world_join = alleurope1.merge(prev_result2 , left_on='ISO_2DIGIT', right_on='occr_country', how='outer')
#world_join = world_join[world_join["occr_country"].isnull()]
world_join

##world_join.drop(columns, axis=1, inplace=True)
world_join['cluster'].fillna(1, inplace=True)

world_join['cluster'] = world_join['cluster'].astype(str).replace('\.0', '', regex=True)
world_join['cluster'] = world_join['cluster'].astype(str)
world_join['cluster'] = world_join['cluster'].str.replace('Nan','1')

cb = world_join[world_join['cluster']=='0']

#cb = usstates_join[(usstates_join['cluster3']==1) | (usstates_join['cluster7']==1)]

non_cb = world_join[world_join['cluster']=='1']
testcb = alleurope1[alleurope1['ISO_2DIGIT'].isin(spatial_list)]


#non_cb = usstates_join[(usstates_join['cluster3']==0) | (usstates_join['cluster7']==0)]
#usstates_join.to_csv('ttest.csv')
sns.set(font_scale=1, rc={'figure.figsize':(200,200)})

#cb.plot(color='gray', edgecolor='white', legend = True, linewidth= 5)

cb['coords'] = cb['geometry'].apply(lambda x: x.representative_point().coords[:])
cb['coords'] = [coords[0] for coords in cb['coords']]
cb['coords']

base = non_cb.plot(color='gray', edgecolor='white', legend = True, linewidth= 10)

testcb.plot(ax=base, color='orange', edgecolor='white', legend = True, linewidth= 10)
cb.plot(ax=base, color='red', edgecolor='white', legend = True, linewidth= 10)

cb.plot(ax=base, color='red', edgecolor='white', legend = True, linewidth= 10)
for idx, row in alleurope1.iterrows():
    #print(row)
    plt.annotate(s=row['CNTRY_NAME'], xy=row['coords'],horizontalalignment='center', fontsize= 80)
    

#for tt,r in zip(text1_statecount, (range(15,0,-2))):
  #  plt.text(-10, r, tt,fontsize=100, ha='left', rotation=0, wrap=True) 

#plt.title('Spatial Autocorrelation Test Map pvalue '+str(pval)+' Frequent Itemset Mining of Adverse Events for Pharmaceutical Drug: '+str(drugname), fontsize=225,y=1.05)
#plt.xlabel('Hierarchical Clustering, cutoff= '+str(cutoff)+ ' Temporal = '+str(temporal)+' for output of '+ str(count_countries)+' European Countries using FAERS Post Market Adverse Events', fontsize=150)
import matplotlib.patches as mpatches
gray_patch = mpatches.Patch(color='gray', label='Basemap')
red_patch = mpatches.Patch(color='orange', label='Spatial Pattern Not Significant')
orange_patch = mpatches.Patch(color='red', label='Significant Spatial Autocorrelation - Pvalue='+str(pval)[1:-1])

plt.legend(handles=[gray_patch,red_patch,orange_patch], loc='lower left',markerscale=10, fontsize=200)

#os.chdir(r"G:\Research\FAERS_Public\Results\Maps\tp10")
os.chdir(r"H:\Research\FAERS_Public\map_igji\20200908")

plt.savefig("spatial_autocorrelation_map"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".png", bbox_inches="tight")
plt.savefig("spatial_autocorrelation_map"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".svg",  bbox_inches="tight")
plt.savefig("spatial_autocorrelation_map"+str(lm)+'_'+str(countofcountries)+"Top_"+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(temporal[0::3])+str(te_num)+str(lm)+"_"+str(version)+".pdf", bbox_inches="tight")


    # plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.png", dpi=900, bbox_inches="tight")
     #   plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.svg", dpi=900, bbox_inches="tight")
      #  plt.savefig("Dendrogram_Tree_cluster_Jaccard_Similiarity_testing_"+str(countofcountries)+", Top "+str(kk)+"_countries_drugname_"+str(drugname)+"_temporal_"+str(y)+"_"+str(lm)+"_version_naive.pdf", dpi=900, bbox_inches="tight")

        
        
plt.show()
#plt.clf()

# %%
maptext
k
len(spatial_list)

# %%
spatial_list

# %%
str(pval)[1:-1]

# %%
ccc

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
import xml.etree.ElementTree as ET
import urllib.request

#url = 'https://dailymed.nlm.nih.gov/dailymed/services/v2/spls/fe9e8b7d-61ea-409d-84aa-3ebd79a046b5.xml'
url = 'https://dailymed.nlm.nih.gov/dailymed/getFile.cfm?setid=a0a046c1-056d-45a9-bfd9-13b47c24f257&type=zip&name=REMICADE'
response = urllib.request.urlopen(url).read()
tree = ET.fromstring(response)
for docTitle in tree.findall('{urn:hl7-org:v3}title'):
    print(docTitle.text)

for compTitle in tree.findall('.//{urn:hl7-org:v3}title'):
    print(compTitle.text)

# %%
links = []
resp = requests.get("https://www.drugs.com/sfx/methotrexate-side-effects.html")
soup = BeautifulSoup(resp.text, "html.parser")

#soup = BeautifulSoup(resp.content,'lxml')
tab = []
table = soup.find('h3', attrs={'class':"list-length-short list-type-word"})
for i, table in enumerate(soup.select('li')):
    tab.append(table)
    #print(table)
#df = pd.read_html(str(tab))
#print( tabulate(df[0], headers='keys', tablefmt='psql') )

# %%
tab

# %%
resp = urllib.request.urlopen("https://www.nhc.noaa.gov/gis/archive_forecast.php?year=2019")
soup = BeautifulSoup(resp, "html.parser")

# %%
zzz

# %%
plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')

plt.title('Hierarchical Clustering (method = complete, min sup=0.2, top (1) frequent items))')
plt.xlabel('dendrogram Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug(lenalidomide)')
plt.ylabel('distance')
plt.box('on')
plt.tight_layout()

#plt.axis([0, 8, 0, 8])


last = Z[-38:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev, linewidth=7.0)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev, linewidth=7.0)
plt.show()
k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
print("clusters:", k)

# %%
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir(r"G:\Research\FAERS\Drug_Spatial\L_B_N_E\Data\Helper_Datasets\shapefiles\USstates")
#plt.title("Etanercept Hierarchical Clustering, method:single, (min sup=0.2, top (2) frequent items), cluster 4")

usstates_shp = gpd.read_file(filename='usstates.shp')

spatial_auto_plot_01 = usstates_shp.join(sstate_01, on='STATE_ABBR')
#spatial_auto_plot_05 = usstates_shp.merge(sstate_05, on='STATE_ABBR')
#spatial_auto_plot_001 = usstates_shp.merge(sstate_001, on='STATE_ABBR')

#cluster_output
#usstates_join = pd.concat([usstates_shp, cluster_output], ignore_index=True)
columns = ['AGE_18_21', 'AGE_22_29', 'AGE_30_39', 'AGE_40_49', 'AGE_50_64',
       'AGE_5_17', 'AGE_65_UP', 'AGE_UNDER5', 'AMERI_ES', 'ASIAN',
       'AVE_FAM_SZ', 'AVE_HH_SZ', 'AVG_SALE97', 'AVG_SIZE97', 'BLACK',
       'CROP_ACR97', 'FAMILIES', 'FEMALES', 'FHH_CHILD', 'HAWN_PI', 'HISPANIC',
       'HOUSEHOLDS', 'HSEHLD_1_F', 'HSEHLD_1_M', 'HSE_UNITS', 'MALES',
       'MARHH_CHD', 'MARHH_NO_C', 'MED_AGE', 'MED_AGE_F', 'MED_AGE_M',
       'MHH_CHILD', 'MULT_RACE', 'NO_FARMS97', 'OTHER', 'OWNER_OCC',
       'ObjectID', 'POP00_SQMI', 'POP09_SQMI', 'POP2000', 'POP2009',
       'RENTER_OCC', 'SQMI', 'STATE_FIPS',
       'SUB_REGION', 'VACANT', 'WHITE']
spatial_auto_plot_01.drop(columns, axis=1, inplace=True)
#spatial_auto_plot_05.drop(columns, axis=1, inplace=True)
#spatial_auto_plot_001.drop(columns, axis=1, inplace=True)

#cb = usstates_join['cluster']
#usstates_join.to_csv('ttest.csv')
sns.set(font_scale=1, rc={'figure.figsize':(200,200)})
spatial_auto_plot_01.plot()
#spatial_auto_plot_05.plot()
#spatial_auto_plot_001.plot()
plt.show()

# %%
#http://pysal.readthedocs.io/en/latest/users/tutorials/autocorrelation.html#global-autocorrelation

import numpy as np
import pysal as ps
#w=ps.lat2W(38,38, rook=False) #This yields a 9x9 matrix
#os.chdir(r"H:\FAERS\weights")
cb = b['cluster2']
w=ps.lat2W(38,1, rook=True)
jc=ps.Join_Counts(cb,w,permutations=999)

jc.bb
jc.bw
jc.ww  
jc.J
len(jc.sim_bb)

print('postive spatial autocorrelation=', jc.p_sim_bb)
#np.mean(jc.sim_bb)
#np.max(jc.sim_bb)
#np.min(jc.sim_bb)

len(jc.sim_bw)
print('negative spatial autocorrelation=',jc.p_sim_bw)
#np.mean(jc.sim_bw)
#np.max(jc.sim_bw)
#np.min(jc.sim_bw)

# %%
pwd

# %%
#http://pysal.readthedocs.io/en/latest/users/tutorials/autocorrelation.html#global-autocorrelation
try:
    
    p_values = []
    import pysal as ps
    list2 = np.linspace(0.10, 1.0, num=10)
    for xy in list2:
        assignments = fcluster(brow_clusters_complete,xy,'distance')  #0.45 e
        labels=lenalid_df.index
        print(set(assignments))

        cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})
        for x in range(1,9):
            column = ('cluster' + str(x))
            cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
            cluster_output[column]
            print('culumns=', str(x))
            cb = usstates_join[column]
            w=ps.lat2W(38,1, rook=True)
            jc=ps.Join_Counts(cb,w,permutations=999)

            jc.bb
            jc.bw
            jc.ww  
            jc.J
            len(jc.sim_bb)
            p_values.append(jc.p_sim_bw)
            cluster_output['p_values_'+str('for_cluster_')+str(x)] = jc.p_sim_bb
            if jc.p_sim_bb<0.01:
                print('very very very very significant__'*50) 
            elif jc.p_sim_bb<0.05:
                print('very significant__'*10)
        
            elif jc.p_sim_bb<0.5:
                print('significant__'*10)  
        
            print('postive spatial autocorrelation=', jc.p_sim_bb)


            len(jc.sim_bw)
            print('negative spatial autocorrelation=',jc.p_sim_bw)
            
        pass
    pass
        
except (AttributeError) as err: #AttributeError,  KeyError
    pass#print('error')

# %%
from scipy.cluster.hierarchy import fcluster
import pysal as ps
list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
#list1 = [erow_clusters_complete, lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete]
#list2 = np.linspace(0.10, 1.0, num=10)
list2 = np.linspace(0.10, 1.0, num=10)
str1 = ''.join(str(e) for e in list1)
for xx in list1:
    for y in list2:
        #print(x+str(y))
        assignments = fcluster(xx,y,'distance')  #0.45 e
        labels=lenalid_df.index
        cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})

        print('cluster cut off point= ', str(y))
        print(set(assignments))
#print('name of cluster =', str(str1))

# %%
from scipy.cluster.hierarchy import fcluster
import pysal as ps

#list1 = [irow_clusters_single, prow_clusters_single, terow_clusters_single, tirow_clusters_single]
list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
#list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]
p_values = []
clusters_assignments = []
clusters_dicts = {}
cutoff = []
#list2 = np.linspace(0.10, 1.0, num=10)
list2 = np.linspace(0.0, 1.0, num=10)
str1 = ''.join(str(e) for e in list1)
for xx in list1:
    for y in list2:
        #for x in range(1,12):#new

    #print(x+str(y))
        assignments = fcluster(xx,y,'distance')  #0.45 e
        labels=lenalid_df.index
        cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})
        #clusters_assignments.append(assignments)
        print('cluster cut off point= ', str(y))############
        print(set(assignments))
        #assgn = assignments
        clusters_assignments.append(assignments)
        cutoff.append(y)
#print('name of cluster =', str(str1))

        for x in range(1,10):
            column = ('cluster' + str(x))
            cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
            cluster_output[column]
            print('culumns=', str(x))
            cb = usstates_join['cluster']#column
            w=ps.lat2W(38,1, rook=True)
            jc=ps.Join_Counts(cb,w,permutations=999)

            jc.bb
            jc.bw
            jc.ww  
            jc.J
            len(jc.sim_bb)
            p_values.append(jc.p_sim_bw)
            cutoff.append(y)
            cluster_output['p_values_'+str('clustercolumn'),str(x)+str('_cutoff'),cutoff[(x-2)]] = jc.p_sim_bb
            if jc.p_sim_bb<0.01:
                print(jc.p_sim_bb)
                print('very very very very significant__'*50) 
            elif jc.p_sim_bb<0.05:
                print('very significant__'*10)
                print(jc.p_sim_bb)
            elif jc.p_sim_bb<0.75:
                print(jc.p_sim_bb)
                print('significant__'*10)  
            
            #print('postive spatial autocorrelation=', jc.p_sim_bb)
#np.mean(jc.sim_bb)
#np.max(jc.sim_bb)
#np.min(jc.sim_bb)

            len(jc.sim_bw)
            #print('negative spatial autocorrelation=',jc.p_sim_bw)
#np.mean(jc.sim_bw)
#np.max(jc.sim_bw)
#np.min(jc.sim_bw)
            
            #p_values
            

            clusters_dicts =dict(zip(p_values, cluster_output['cluster']))

# %%
from scipy.cluster.hierarchy import fcluster
import pysal as ps

#list1 = [irow_clusters_single, prow_clusters_single, terow_clusters_single, tirow_clusters_single]
#list1 = [lrow_clusters_single, brow_clusters_single, nrow_clusters_single, erow_clusters_single]
list1 = [lrow_clusters_complete, brow_clusters_complete, nrow_clusters_complete, erow_clusters_complete]
p_values = []
#clusters_assignments = []
clusters_dicts = {}
cutoff = []
#list2 = np.linspace(0.10, 1.0, num=10)
list2 = np.linspace(0.0, 1.0, num=10)
str1 = ''.join(str(e) for e in list1)

#for xx in list1:
for y in list2:

    assignments = fcluster(brow_clusters_complete,y,'distance')  #0.45 e
    labels=lenalid_df.index
    cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})
        
    print('cluster cut off point= ', str(y))############
    print(set(assignments))
       # print(set(assignments[:-1]))
        #assgn = assignments
    clusters_assignments = []
    clusters_assignments.append(assignments)
    mx = np.max(clusters_assignments)
    mx = mx+1
    print(mx)
    cutoff.append(y)

    #for x in range(1,mx):
        #column = ('cluster' + str(x))
        #cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
    clu = pd.get_dummies(cluster_output['cluster'])
    merged = pd.merge(left=cluster_output, left_index=True, right=clu, right_index=True, how='inner')
     
    #merged[column]
    #print('column=', str(x))
    #cb = usstates_join[column]

#cluster_output
#merged['cluster1']

# %%
for x,y,z in zip(p_values,list2,clusters_assignments):
    print(x,y,np.unique(z))
    #cluster_output['p_values_'+str('clustercolumn'),str(x)+str('_cutoff'),str(y)] = jc.p_sim_bb

# %%
clusters_dicts

# %%
os.chdir(r"G:\Research\FAERS\Drug_Spatial\L_B_N_E\Data\Analysis_ready_data\Approri\summary_of_approri_dataset\spatial_auto\pvalue\top2")
#cluster_output.to_csv("pvalue_top2_LBNE_singlev2.csv")
cluster_output
#see if can put list in columns 
#clusters_dicts

# %%
#cluster_output
list2 = np.linspace(0.0, 1.0, num=11)
#cutoff  = []
#for y in list2:
 #   print(y)
  #  cutoff.append(y)
    #print(cutoff[y])
for x in range(0,12):
    print(x)
    print(cutoff[(x-2)])
list2

# %% [markdown]
# for x in range(1,5):
#     column = ('cluster' + str(x))
#     cluster_output[column] = (cluster_output['cluster'] ==x).astype(int)
#     cluster_output[column]
# cluster_output

# %%
clusters_dicts#
#clusters_assignments = np.unique(clusters_assignments)
#clusters_assignments
#p_values

# %%
len(p_values)/11

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
#os.chdir(r"H:\FAERS\weights\sp_auto")
#cluster_output = pd.read_csv('spatial_auto_cutooff_0dot65_lenalid_method_complete.csv')
#cluster_output
clusters_dicts1 = {}
clusters_dicts2 = {}

#clusters_dicts1 =dict(clusters_assignments)
clusters_dicts2 =dict(p_values)

#clusters_dicts1
clusters_dicts2

# %%
#http://pysal.readthedocs.io/en/latest/users/tutorials/autocorrelation.html#global-autocorrelation

import numpy as np
import pysal as ps
#w=ps.lat2W(38,38, rook=False) #This yields a 9x9 matrix
os.chdir(r"H:\FAERS\weights")
cb = usstates_join['cluster4']
w=ps.lat2W(38,1, rook=True)
jc=ps.Join_Counts(cb,w,permutations=999)

jc.bb
jc.bw
jc.ww  
jc.J
len(jc.sim_bb)

print('postive spatial autocorrelation=', jc.p_sim_bb)
#np.mean(jc.sim_bb)
#np.max(jc.sim_bb)
#np.min(jc.sim_bb)

len(jc.sim_bw)
print('negative spatial autocorrelation=',jc.p_sim_bw)
#np.mean(jc.sim_bw)
#np.max(jc.sim_bw)
#np.min(jc.sim_bw)

# %%
plt.clf()

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

Sl = dendrogram(lrow_clusters_single, labels=lenalid_df.index, show_leaf_counts=True)
#Si = dendrogram(irow_clusters_single, leaf_rotation=90,  color_threshold=0.6, labels=lenalid_df.index)

#Sp = dendrogram(prow_clusters_single, labels=bupreno_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Ste = dendrogram(terow_clusters_single, labels=etanerc_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Sti = dendrogram(tirow_clusters_single, labels=nataliz_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram

#Sl = dendrogram(lrow_clusters_single, labels=lenalid_df.index, show_leaf_counts=True)
Sl = dendrogram(lrow_clusters_single, leaf_rotation=90,  color_threshold=0.6, labels=lenalid_df.index)

#Sb = dendrogram(brow_clusters_single, labels=bupreno_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Se = dendrogram(erow_clusters_single, labels=etanerc_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Sn = dendrogram(nrow_clusters_single, labels=nataliz_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)

# %%
#single
os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot")
#plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
plt.box('off')
plt.tight_layout()
plt.axhline(y=0.6, c='grey', lw=1, linestyle='dashed')


#plt.title("lenalid Hierarchical Clustering (method = single)")

#plt.savefig("lenalid_38_clusters_single.png", dpi=300)

#plt.title("bupreno Hierarchical Clustering (method = single)")
#plt.savefig("bupreno_38state_clusters_single.png", dpi=300)


#plt.title("etanerc Hierarchical Clustering (method = single)")
#plt.savefig("etanerc_38state_clusters_single.png", dpi=300)


#plt.title("nataliz Hierarchical Clustering (method = single)")
#plt.savefig("nataliz_38state_clusters_single.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram
import scipy.cluster.hierarchy as sch
import seaborn as sns


#dendrogram(lrow_clusters_complete, labels=lenalid_df.index)
dendrogram(brow_clusters_complete, labels=bupreno_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Ce = dendrogram(erow_clusters_complete, labels=etanerc_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)
#Cn = dendrogram(nrow_clusters_complete, labels=nataliz_df.index, show_leaf_counts=True, leaf_font_size=8, get_leaves=True)

# %%
#complete
#os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot\dendogram_topten")
plt.tick_params(axis='both', left='on', top='off', right='on', bottom='on', labelleft='on', labeltop='off', labelright='on', labelbottom='on')
plt.box('off')
plt.tight_layout()
#plt.figure(figsize=(8,8))


#fig.subplots_adjust(bottom = 0)
#fig.subplots_adjust(top = 1)
#fig.subplots_adjust(right = 1)
#fig.subplots_adjust(left = 0)

#plt.title("lenalid Hierarchical Clustering (method = complete, min sup=0.2, top five frequent items)")
#plt.savefig("lenalid_38_clusters_complete_topten_minsup0dot2.png", dpi=100)

#plt.title("bupreno Hierarchical Clustering (method = complete, min sup=0.2, top five frequent items)")
#plt.savefig("bupreno_38state_clusters_complete_topten_minsup0dot2.png", dpi=300)


#plt.title("etanerc Hierarchical Clustering (method = complete, min sup=0.2, top five frequent items))")
#plt.savefig("etanerc_38state_clusters_complete_topten_minsup0dot2.png", dpi=300)


#plt.title("nataliz Hierarchical Clustering (method = complete, min sup=0.2, top five frequent items)")
#plt.savefig("nataliz_38state_clusters_complete_topten_minsup0dot2.png", dpi=300)
#plt.savefig('out.png', dpi=150) ###############################################try this

plt.show()

    #pass#print('error')

# %%
plt.clf()   # Clear figure
interfe_distance2 = squareform(pdist(interfe_distance1))
plastic_distance2 = squareform(pdist(plastic_distance1))
teripar_distance2 = squareform(pdist(teripar_distance1))
tiotrop_distance2 = squareform(pdist(tiotrop_distance1))

# %%
interfe_distance = 1-interfe_df
plastic_distance = 1-plastic_df
teripar_distance = 1-teripar_df
tiotrop_distance = 1-tiotrop_df

from scipy.cluster.hierarchy import fcluster

assignments = fcluster(irow_clusters_complete,0.7,'distance')  #0.45 e
labels=interfe_df.index
print(set(assignments))

cluster_output = pd.DataFrame({'STATE_ABBR':labels , 'cluster':assignments})

cluster_output['cluster1'] = (cluster_output['cluster'] ==1).astype(int)
cluster_output['cluster2'] = (cluster_output['cluster'] ==2).astype(int)
cluster_output['cluster3'] = (cluster_output['cluster'] ==3).astype(int)
cluster_output['cluster4'] = (cluster_output['cluster'] ==4).astype(int)
cluster_output['cluster5'] = (cluster_output['cluster'] ==5).astype(int)
cluster_output['cluster6'] = (cluster_output['cluster'] ==6).astype(int)
cluster_output['cluster7'] = (cluster_output['cluster'] ==7).astype(int)
cluster_output['cluster8'] = (cluster_output['cluster'] ==8).astype(int)
cluster_output['cluster9'] = (cluster_output['cluster'] ==9).astype(int)
cluster_output['cluster10'] = (cluster_output['cluster'] ==10).astype(int)
cluster_output['cluster11'] = (cluster_output['cluster'] ==11).astype(int)
cluster_output['cluster12'] = (cluster_output['cluster'] ==12).astype(int)
cluster_output['cluster13'] = (cluster_output['cluster'] ==13).astype(int)
cluster_output['cluster14'] = (cluster_output['cluster'] ==14).astype(int)
cluster_output['cluster15'] = (cluster_output['cluster'] ==15).astype(int)
cluster_output['cluster16'] = (cluster_output['cluster'] ==16).astype(int)
cluster_output['cluster17'] = (cluster_output['cluster'] ==17).astype(int)
cluster_output['cluster18'] = (cluster_output['cluster'] ==18).astype(int)
cluster_output['cluster19'] = (cluster_output['cluster'] ==19).astype(int)
cluster_output['cluster20'] = (cluster_output['cluster'] ==20).astype(int)
cluster_output['cluster21'] = (cluster_output['cluster'] ==21).astype(int)
cluster_output['cluster22'] = (cluster_output['cluster'] ==22).astype(int)
cluster_output['cluster23'] = (cluster_output['cluster'] ==23).astype(int)
cluster_output['cluster24'] = (cluster_output['cluster'] ==24).astype(int)
cluster_output['cluster25'] = (cluster_output['cluster'] ==25).astype(int)
cluster_output['cluster26'] = (cluster_output['cluster'] ==26).astype(int)
cluster_output['cluster27'] = (cluster_output['cluster'] ==27).astype(int)
cluster_output['cluster28'] = (cluster_output['cluster'] ==28).astype(int)
cluster_output['cluster29'] = (cluster_output['cluster'] ==29).astype(int)

#os.chdir(r"H:\FAERS\weights\sp_auto")

#cluster_output.to_csv('spatial_auto_cutooff_0dot65_lenalid_method_complete.csv')

(cluster_output)

# %%
#single
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
#os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot")



interfe_distance = 1-interfe_df
plastic_distance = 1-plastic_df
teripar_distance = 1-teripar_df
tiotrop_distance = 1-tiotrop_df

linkage = hc.linkage(sp.distance.squareform(interfe_distance2), method='complete')
sns.clustermap(interfe_distance, row_linkage=linkage, col_linkage=linkage)

plt.title("interfe Hierarchical Clustering (min sup=0.2, top five frequent items)")
plt.savefig("interfe_38_clusters_complete_complete_seaborn_topfive_minsup0dot2.png", dpi=300)


plt.show()

# %%
lenalid_distance2 = squareform(pdist(lenalid_distance1))
bupreno_distance2 = squareform(pdist(bupreno_distance1))
etanerc_distance2 = squareform(pdist(etanerc_distance1))
nataliz_distance2 = squareform(pdist(nataliz_distance1))

# %%
#complete
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
#os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot")

#lenalid_distance = 1-lenalid_df
#bupreno_distance = 1-bupreno_df
#etanerc_distance = 1-etanerc_df
#nataliz_distance = 1-nataliz_df


linkage = hc.linkage(sp.distance.squareform(lenalid_distance2), method='complete')
sns.clustermap(lenalid_distance2, row_linkage=linkage, col_linkage=linkage)

#plt.title("interfe Hierarchical Clustering (min sup=0.2, top five frequent items)")
#plt.savefig("interfe_38_clusters_complete_complete_seaborn_topfive_minsup0dot2.png", dpi=300)


plt.show()

# %%
#complete
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc
#os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot")

lenalid_distance = 1-lenalid_df
bupreno_distance = 1-bupreno_df
etanerc_distance = 1-etanerc_df
nataliz_distance = 1-nataliz_df

#linkage = hc.linkage(sp.distance.squareform(etanerc_distance), method='complete')
sns.clustermap(etanerc_distance, row_linkage=linkage, col_linkage=linkage)

#plt.title("lenalid Hierarchical Clustering (min sup=0.2, top five frequent items)")
#plt.savefig("lenalid_38_clusters_complete_seaborn_topfive_minsup0dot2.png", dpi=300)

#plt.title("bupreno Hierarchical Clustering (min sup=0.2, top five frequent items)")
#plt.savefig("bupreno_38state_clusters_complete_seaborn_topfive_minsup0dot2.png", dpi=300)


#plt.title("etanerc Hierarchical Clustering (min sup=0.2, top (1) frequent items)")
#plt.savefig("etanerc_38state_clusters_complete_seaborn_top_one_minsup0dot2.png", dpi=300)


#plt.title("nataliz Hierarchical Clustering (min sup=0.2, top five frequent items)")
#plt.savefig("nataliz_38state_clusters_complete_seaborn_topfive_minsup0dot2.png", dpi=300)

plt.show()

# %%
import seaborn as sns
import scipy.spatial as sp, scipy.cluster.hierarchy as hc

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly
X = bupreno_df

dendro = ff.create_dendrogram(X,labels=states)
dendro['layout'].update({'width':800, 'height':500})
py.iplot(dendro, filename='simple_dendrogram')

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly 
plotly.tools.set_credentials_file(username='ahmedaskar64', api_key='Qw3ldiyA0ZKW2iELu4ZA')

import numpy as np


X = np.random.rand(38, 38)
states = ["AR", "AZ", "CA", "CO", "FL", "GA","HI", "IA", "IL", "IN", "KS", "KY", "MA","MD","ME", "MI", "MN", "MS", "NC", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "TN", "TX", "UT", "VA", "WA", "WI", "WV"]
fig = ff.create_dendrogram(lenalid_distance, orientation='left', labels=states)
fig['layout'].update({'width':800, 'height':800})
py.iplot(fig, filename='dendrogram_with_labels')

# %%
#cluster_output[column]
cutoff

# %%
states1 = ["AR", "AZ", "CA", "CO", "FL", "GA","HI", "IA", "IL", "IN", "KS", "KY", "MA","MD","ME", "MI", "MN", "MS", "NC", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "TN", "TX", "UT", "VA", "WA", "WI", "WV"]
columns = ['AR', 'AZ', 'CA', 'CO', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'KY',
       'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'NC', 'NE', 'NH', 'NJ', 'NM', 'NV',
       'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'TN', 'TX', 'UT', 'VA', 'WA',
       'WI', 'WV']
len(columns)
#38*38
#lenalid_distance2.shape
l.columns

# %% [markdown]
# os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\weights")
# lenalid_df.to_csv('lenalid_df_similarity.csv')
# bupreno_df.to_csv('bupreno_df_similarity.csv')
# etanerc_df.to_csv('etanerc_df_similarity.csv')
# nataliz_df.to_csv('nataliz_df_similarity.csv')
#
#
#
# l=(1-lenalid_df)
# #print(l)
# b=(1-bupreno_df)
# print(b)
# e=(1-etanerc_df)
# #print(e)
# n=(1-nataliz_df)
# #print(n)
# l.to_csv('lenalid_df_similarity_used_for_weights.csv')
# b.to_csv('bupreno_df_similarity_used_for_weights.csv')
# e.to_csv('etanerc_df_similarity_used_for_weights.csv')
# n.to_csv('nataliz_df_similarity_used_for_weights.csv')
#
# lenalid_distance = 1-lenalid_df
# bupreno_distance = 1-bupreno_df
# etanerc_distance = 1-etanerc_df
# nataliz_distance = 1-nataliz_df

# %%
#possible weight
l=(1-lenalid_df)
df_lenalid_sig = pd.DataFrame(l)
#df_lenalid.loc['Total']= df_lenalid.sum()
#df_lenalid_sig['Mean']= df_lenalid_sig.mean()
#df_lenalid_sig['Median'] =df_lenalid_sig.median()
#df_lenalid_sig.loc['Mean']= df_lenalid_sig.mean(axis=1)
#df_lenalid['Total'] = df_lenalid.sum(axis=1)
df_lenalid_sig



b=(1-bupreno_df)
df_bupreno_sig = pd.DataFrame(b)
#df_bupreno.loc['Total']= df_bupreno.sum()
#df_bupreno_sig['Mean']= df_bupreno_sig.mean()
#df_bupreno_sig['Median'] =df_bupreno_sig.median()
#df_bupreno_sig.loc['Mean']= df_bupreno_sig.mean(axis=1)
#df_bupreno['Total'] = df_bupreno.sum(axis=1)
df_bupreno_sig


e=(1-etanerc_df)
df_etanerc_sig = pd.DataFrame(e)
#df_etanerc.loc['Total']= df_etanerc.sum()
#df_etanerc_sig['Mean']= df_etanerc_sig.mean()
#df_etanerc_sig['Median'] =df_etanerc_sig.median()
#df_etanerc_sig.loc['Mean']= df_etanerc_sig.mean(axis=1)
#df_etanerc['Total'] = df_etanerc.sum(axis=1)
df_etanerc_sig


n=(1-nataliz_df)
df_nataliz_sig = pd.DataFrame(n)
#df_nataliz.loc['Total']= df_nataliz.sum() # for the total at the bottom of df
#df_nataliz_sig['Mean']= df_nataliz_sig.mean()
#df_nataliz_sig['Median'] =df_nataliz_sig.median()
#df_nataliz_sig.loc['Mean']= df_nataliz_sig.mean(axis=1)
#df_nataliz['Total'] = df_nataliz.sum(axis=1) # for the column total
df_nataliz_sig

# %%
dd = np.array(n)
dd.shape

# %%
nn = b['OH']
nzz = stats.zscore(nn)
p_valuesn = stats.norm.sf(abs(nzz))
p_valuesn

# %%
from scipy import stats
#import scipy

dd = np.array(e)
#dd
zscore = stats.zscore(dd, axis=1, ddof=0)
zscore
p_values = stats.norm.sf(abs(zscore))
columns = ['AR', 'AZ', 'CA', 'CO', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'KY',
       'MA', 'MD', 'ME', 'MI', 'MN', 'MS', 'NC', 'NE', 'NH', 'NJ', 'NM', 'NV',
       'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'TN', 'TX', 'UT', 'VA', 'WA',
       'WI', 'WV']
df_pv = pd.DataFrame(p_values, index=columns, columns=columns)
sig = df_pv < 0.1
sig

# %%
os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot\significant_testing_plots")
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale=7, rc={'figure.figsize':(150,150)})

ax = sns.heatmap(sig,annot=True)
#lenalid
#bupreno
#etanerc
#nataliz
plt.title("etanerc jaggard distance significant testing (min sup=0.2, top ten frequent items)")
plt.savefig("etanerc_signficance_lessthan0dot1_output_38states__topten_minsup0dot2.png")
plt.show()

# %%
os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\plot\jaggard")
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#sns.set(font_scale=7, rc={'figure.figsize':(150,150)})
sns.set(rc={'figure.figsize':(150,150)})
#ax.invert_yaxis()

f,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,sharey=True)
f.suptitle("Jaccard Index Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug top ten, minsup 0.2", fontsize=100)
#f.tight_layout()
#f.subplots_adjust(top=5.2)
ax1.title.set_text('Jaccard Index Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug(Lenalidomide)')
ax2.title.set_text('Jaccard Index Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug(Natalizumab)')
ax3.title.set_text('Jaccard Index Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug(Etanercept)')
ax4.title.set_text('Jaccard Index Similiarity between US States and Post Market Adverse Events for Pharmaceutical Drug(Buprenorphine)')


g1 = sns.heatmap(lenalid_df,annot=True, linewidths=1,vmin=0, vmax=1, xticklabels=1 , yticklabels=True, cmap="coolwarm",  center=.5,ax=ax1)#YlGnBu
g1.set_ylabel('lenalidomide')
g1.set_xlabel('')
#g1.invert_yaxis()


g2 = sns.heatmap(nataliz_df,annot=True,linewidths=1,vmin=0, vmax=1, xticklabels=1 , yticklabels=True, cmap="coolwarm",  center=.5,ax=ax2)
g2.set_ylabel('natalizumab')
g2.set_xlabel('')

g3 = sns.heatmap(etanerc_df,annot=True,linewidths=1,vmin=0, vmax=1, xticklabels=1 , yticklabels=True, cmap="coolwarm",  center=.5,ax=ax3)
g3.set_ylabel('etanercept')
g3.set_xlabel('')

g4 = sns.heatmap(bupreno_df,annot=True, linewidths=1,vmin=0, vmax=1, xticklabels=1 , yticklabels=True, cmap="coolwarm",  center=.5,ax=ax4)
g4.set_ylabel('buprenorphine')
g4.set_xlabel('')



f.savefig("jaggard_index_topten_minsup0dot2_38states.pdf")
#sns.plt.show()

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
#d = pd.DataFrame(data=rs.normal(size=(100, 26)),
 #                columns=list(ascii_letters[26:]))

# Compute the correlation matrix
lenalid_corr = lenalid_df.corr()
nataliz_corr = nataliz_df.corr()
etanerc_corr = etanerc_df.corr()
bupreno_corr = bupreno_df.corr()




# Generate a mask for the upper triangle
mask1 = np.zeros_like(lenalid_corr, dtype=np.bool)
mask2 = np.zeros_like(nataliz_corr, dtype=np.bool)
mask3 = np.zeros_like(etanerc_corr, dtype=np.bool)
mask4 = np.zeros_like(bupreno_corr, dtype=np.bool)



mask1[np.triu_indices_from(mask1)] = True
mask2[np.triu_indices_from(mask2)] = True
mask3[np.triu_indices_from(mask3)] = True
mask4[np.triu_indices_from(mask4)] = True




# Set up the matplotlib figure
#f, ax = plt.subplots(figsize=(5, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
#fig, axs = plt.subplots(ncols=4)
fig = plt.figure()
ax1 = fig.add_subplot(111) # (211)
#ax2 = fig.add_subplot(212)
#ax3 = fig.add_subplot(221)
#ax4 = fig.add_subplot(222)


sns.heatmap(lenalid_corr, mask=mask1, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, ax = ax1, cbar_kws={"shrink": .5})

#sns.heatmap(nataliz_corr, mask=mask2, cmap=cmap, vmax=.3, center=0,
 #           square=True, linewidths=.5,ax = ax2, cbar_kws={"shrink": .5})

#sns.heatmap(etanerc_corr, mask=mask3, cmap=cmap, vmax=.3, center=0,
 #           square=True, linewidths=.5, cbar_kws={"shrink": .5})

#sns.heatmap(bupreno_corr, mask=mask4, cmap=cmap, vmax=.3, center=0,
  #          square=True, linewidths=.5,  cbar_kws={"shrink": .5})
fig.savefig("output1.svg")

# %%
#os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\bydrug")
d = state('VA')
d.info()
#NY =131595
#TX = 133646
#CA = 209147 
#IL = 80628 
#CO = 30489 
#VA = 71300

#etanercept = 33749 
#natalizumab = 32395 
#buprenorphine = 15102
#lenalidomide = 29395

# %%
os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\bydrug3")
from __future__ import division
drugs = ['etanercept', 'natalizumab', 'buprenorphine', 'lenalidomide' ]#'etanercept','natalizumab', 'buprenorphine', 'lenalidomide'

d = {}
for drugname in drugs:
    d = {}
    x = drug(drugname)

    dataset = []
    for xx in x['PT_All_U']:
        dataset.append(xx.split(','))
        pass
    import pandas as pd
    from mlxtend.preprocessing import OnehotTransactions

    oht = OnehotTransactions()
    oht_ary = oht.fit(dataset).transform(dataset)
    df4 = pd.DataFrame(oht_ary, columns=oht.columns_)
    df4
    from mlxtend.frequent_patterns import apriori

    frequent_itemsets = apriori(df4, min_support=0.05, use_colnames=True)#0.05
    frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
    filename = drugname[:7]
    frequent_itemsets.to_csv(filename+'.csv', float_format='%.5f')
    print(filename)
print('alllll Done')

# %%
os.chdir(r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\bystate3")
from __future__ import division
states = ['NY', 'TX', 'CA', 'IL', 'CO', 'VA']


d = {}
#for state in states:
for st in states:
        #print (state,drugname)
    d = {}
    x = state(st)
    #x=str(x)
        
        #x =xyz('TX', 'natalizumab')

#dataset = []
    dataset = []
    for xx in x['PT_All_U']:
        dataset.append(xx.split(','))
        pass
#print(dataset)
    import pandas as pd
    from mlxtend.preprocessing import OnehotTransactions

    oht = OnehotTransactions()
    oht_ary = oht.fit(dataset).transform(dataset)
    df4 = pd.DataFrame(oht_ary, columns=oht.columns_)
    df4
    from mlxtend.frequent_patterns import apriori

#apriori(df4, min_support=0.01)
#apriori(df4, min_support=0.01, use_colnames=True)
    frequent_itemsets = apriori(df4, min_support=0.05, use_colnames=True)#0.05
    frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
    filename = st
    frequent_itemsets.to_csv(filename+'.csv', float_format='%.5f')
    print(filename)
print('alllll Done')

# %%
#check if it saved and start here. after do the chiaquare thest

# %%
#NY =131595
#TX = 133646
#CA = 209147 
#IL = 80628 
#CO = 30489 
#VA = 71300

#etanercept = 33749 
#natalizumab = 32395 
#buprenorphine = 15102
#lenalidomide = 29395 

states = ['NY', 'TX', 'CA', 'IL', 'CO', 'VA']
totalcount = [131595, 133646, 209147, 80628, 30489, 71300]

path = r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\bystate2"
import glob
files = os.chdir(path)
for x in os.listdir(files):
    for xx,yy in zip(states,totalcount):
        if x[:2] == xx:
            print(xx)
            d = pd.read_csv(x)
            d['itemsets'] = d.itemsets.str.strip(']')
            d['itemsets'] = d.itemsets.str.strip('[')
            d['itemsets'] = d.itemsets.str.strip('"')
            d['itemsets'] = d.itemsets.str.strip('"')
            d['count_bystate']=d['support']*yy
            u = d['count_bystate']
            filename = xx+".csv"
            d.to_csv(filename)
            print(filename)

print('alllll Done')

# %%
drugs = ['etanercept', 'natalizumab', 'buprenorphine', 'lenalidomide']
totalcount = [33749, 32395, 15102, 29395]

path = r"C:/Users/Ahmed.Askar/Desktop/textdump/temp/bydrug2/"
import glob
files = os.chdir(path)
for x in os.listdir(files):
    #print(x[:-4])
    for xx,yy in zip(drugs,totalcount):
        if x[:-4] == xx[:7]:
            d = pd.read_csv(x)
            d['count_bydrugs']=d['support']*yy
    #        u = d['count_bydrugs']
            filename = xx[:7]+".csv"
            d.to_csv(filename)
            print(filename)

print('alllll Done')

# %%
drugs = ['etanercept', 'natalizumab', 'buprenorphine', 'lenalidomide']

key_list = []
value_list = []
value_list2 = []
value_list3 = []

import re
path = r"C:/Users/Ahmed.Askar/Desktop/textdump/temp/bydrug2/"
import glob
files = os.chdir(path)
for x in os.listdir(files):
    for xx in drugs:
        if x[:-4] == xx[:7]:
            d = pd.read_csv(x)
            d['drug'] = xx
            d.set_index('itemsets', inplace=True)
            d['itemsets'] = d.index
            #print(d)
            for i, row in d.iterrows():
                #print(i)
                #print(row['itemsets'])#itemsets, #count_bydrugs
                s = row['itemsets']
                if s.find("injectionsitepain") != -1:#drugineffective
                    #print(i)
                    #print(row['itemsets'], row['count_bydrugs'],row['drug'] )
                    key = row['drug']
                    value = row['count_bydrugs']
                    value2 = row['support']
                    value3 = row['itemsets']
                    key_list.append(key)
                    value_list.append(value)
                    value_list2.append(value2)
                    value_list3.append(value3)

    

                    dfdrug = pd.DataFrame({'drug': key_list, 'count_bydrugs': value_list, 'ratio': value_list2, 'items': value_list3})  
                    dfdrug.set_index('drug', inplace=True)
                    #dfdrug['state'] = d.index
dfdrug

# %%
states = ['NY', 'TX', 'CA', 'IL', 'CO', 'VA']

key_list = []
value_list = []
value_list2 = []

import re
path = r"C:/Users/Ahmed.Askar/Desktop/textdump/temp/bystate2/"
import glob
files = os.chdir(path)
for x in os.listdir(files):
    #print(x[:-4])
    for xx in states:
        #print(xx)
        if x[:-4] == xx:
            d = pd.read_csv(x)
            d['state'] = xx
            d.set_index('itemsets', inplace=True)
            d['itemsets'] = d.index
        
            #print(d)
            for i, row in d.iterrows():
                #print(i)
                #print(row['itemsets'])#itemsets, #count_bydrugs
                s = row['itemsets']
                if s.find("injectionsitepain") != -1:
                    #print(i)
                    #print(row['itemsets'], row['count_bystate'],row['state'] )
                    key = row['state']
                    value = row['count_bystate']
                    value2 = row['itemsets']

                    key_list.append(key)
                    value_list.append(value)
                    value_list2.append(value2)


    

                    dfstate = pd.DataFrame({'state': key_list, 'count_bystate': value_list, 'items': value_list2})  
                    dfstate.set_index('state', inplace=True)
                    #dfstate['state'] = d.index
dfstate

# %%
state_drug = ['CA_bupreno', 'CA_etanerc', 'CA_lenalid', 'CA_nataliz', 'CO_bupreno', 'CO_etanerc', 'CO_lenalid', 'CO_nataliz', 
         'IL_bupreno', 'IL_etanerc', 'IL_lenalid', 'IL_nataliz', 'NY_bupreno', 'NY_etanerc', 'NY_lenalid', 'NY_nataliz', 
         'TX_bupreno', 'TX_etanerc', 'TX_lenalid', 'TX_nataliz', 'VA_bupreno', 'VA_etanerc', 'VA_lenalid', 'VA_nataliz']
totalcount = [2136, 3721, 2636, 2309, 462, 572, 166, 1025,
             436, 1531, 683, 1287, 747, 2164, 856, 2201,
             874, 2688, 2207, 1861, 381, 924, 360, 1053]
key_list = []
value_list = []
value_list2 = []

path = r"C:\Users\Ahmed.Askar\Desktop\textdump\temp\by6state_4drug"
import re
import glob
files = os.chdir(path)
dicts2 = {}
for x in os.listdir(files):
   # print(x[:-4], end=(", "))
    for xx,yy in zip(state_drug,totalcount):
        if x[:-4] == xx:
            #filename1 = xx

            #filename.append(filename1)
            d = pd.read_csv(x)
            d['state'] = xx[:-8]
            d['drug'] = xx[3:]
            d['count_bystate_drug']=d['support']*yy
            d.set_index('itemsets', inplace=True)
            d['itemsets'] = d.index
            for i, row in d.iterrows():
                #print(i)
                #print(row['itemsets'])#itemsets, #count_bydrugs
                s = row['itemsets']
                if s.find("injectionsitepain") != -1:
                    #print(i)
                   # print(row['itemsets'], row['count_bystate_drug'],row['state'] )
                    key = row['state']
                    value = row['count_bystate_drug']
                    value2 = row['drug']

                    key_list.append(key)
                    value_list.append(value)
                    value_list2.append(value2)


    

                    dfstate_drug = pd.DataFrame({'state': key_list, 'count_bystate_drugs': value_list, 'drug': value_list2})  
                    dfstate_drug.set_index('state', inplace=True)
                    #dfstate_drug['state'] = d.index
dfstate_drug

# %%
print(dfstate_drug['count_bystate_drugs'])
print(dfstate['count_bystate'])
sum(dfstate_drug['count_bystate_drugs'])

# %%
#observed1 = dfstate_drug.loc['NY']['count_bystate_drug']
observed1 = dfstate_drug['count_bystate_drugs']

#national_ratios1 =  dfstate.loc['NY']['count_bystate_drug']
national_ratios1 =  dfstate['count_bystate']

expected1  =  national_ratios1 * sum(dfstate_drug['count_bystate_drugs'])
chi_squared_stat1 = (((observed1-expected1)**2)/expected1).sum()

print(chi_squared_stat1)

# %%
crit = stats.chi2.ppf(q = 0.95, # Find the critical value for 95% confidence*
                      df = 5)   # Df = number of variable categories - 1

print("Critical value")
print(crit)

p_value = 1 - stats.chi2.cdf(x=chi_squared_stat1,  # Find the p-value
                             df=5)
print("P value")
print(p_value)

# %%
#nataliz_df#lenalid_df
t = np.array(nataliz_df)
tt = np.array(lenalid_df)

sample = []
for x,y in zip(t,tt):
    x = 1-x
    y = 1-y
    sample.append(x)
    sample.append(y)
print(sample)
